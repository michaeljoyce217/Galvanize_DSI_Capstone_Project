# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('data/crime_csv_all_years.csv',parse_dates={'dttime':[1,2,3]}, keep_date_col=True)

# %%
df['day_of_week']=df['dttime'].dt.weekday_name

# %%
df_temp=df.copy()

# %%
df_temp.head()
# Out:
#       dttime                        TYPE  YEAR MONTH DAY  HOUR  MINUTE  \
# 0 2003-11-23          Theft from Vehicle  2003    11  23   0.0     1.0
# 1 2003-05-09          Theft from Vehicle  2003     5   9  18.0     0.0
# 2 2003-03-09    Offence Against a Person  2003     3   9   NaN     NaN
# 3 2003-01-20    Offence Against a Person  2003     1  20   NaN     NaN
# 4 2003-02-07  Break and Enter Commercial  2003     2   7   0.0    30.0
#
#                HUNDRED_BLOCK              NEIGHBOURHOOD          X  \
# 0          13XX W GEORGIA ST  Central Business District  490745.08
# 1             30XX W 8TH AVE                  Kitsilano  487465.51
# 2  OFFSET TO PROTECT PRIVACY                        NaN       0.00
# 3  OFFSET TO PROTECT PRIVACY                        NaN       0.00
# 4           71XX VICTORIA DR        Victoria-Fraserview  495196.35
#
#             Y day_of_week
# 0  5459529.81      Sunday
# 1  5456929.11      Friday
# 2        0.00      Sunday
# 3        0.00      Monday
# 4  5451832.55      Friday

# %%
df2=df_temp.dropna()
#remove missing data, all (or nearly all) of which is the non-property crime data

# %%
df3=df2.rename(index=str, columns={"YEAR": "year", "MONTH": "month", "DAY":"day","HOUR":"hour", "MINUTE":"minute", "NEIGHBOURHOOD":"neighborhood"})
#rename columns as all caps is annoying

# %%
df4=df3.sort_values(['year','month','day','hour','minute'])
#sort by date

# %%
df5=df4.drop(['minute', 'HUNDRED_BLOCK','TYPE'], axis=1)
#remove extraneous data

# %%
df6=df5.apply(pd.to_numeric, errors='ignore')

# %%
#bin by 12am-8am, 8am-4pm, 4pm -12am
hourbins = [-0.1,8.0,16.0,24.1]
hourlabels = ['1200am-0759am', '0800am-0359pm', '0400pm-1159pm']
df6['day_segment'] = pd.cut(df6["hour"], bins=hourbins,labels=hourlabels)

# %%
df7=df6[['year', 'month', 'day', 'day_segment', 'neighborhood']]
#group by neighborhood, by day_segment

# %%
df8=df7.groupby(df7.columns.tolist()).size()

# %%
df9=pd.DataFrame(df8).reset_index()

# %%
df10=df9.rename(index=str, columns={ 0 :"number_of_crimes"})

# %%
df_final=df10.copy()

# %%
wdf=pd.read_csv('data/BA_weather_data.csv')

# %%
wdf_temp=wdf.copy()

# %%
wdf2=wdf_temp[[' YEARMODA', 'TMAX', 'TMIN','PRCP']]

# %%
wdf3=wdf2.rename(index=str, columns={ " YEARMODA":"date","PRCP": "prcp", "TMAX":"tmax","TMIN":"tmin"})

# %%
def get_year(x):
    return int (str(x)[0:4])

def get_month(x):
    return int (str(x)[4:6])

def get_day(x):
    return int(str(x)[6:8])

def get_prcp(x):
    return float(x[1:5])
    
get_year(20030101)
# Out:
# 2003

# %%
wdf3['year'] = wdf3['date'].apply(get_year)
wdf3['month'] =  wdf3['date'].apply(get_month)
wdf3['day'] = wdf3['date'].apply(get_day)
wdf3['precipitation']=wdf3['prcp'].apply(get_prcp)

# %%
wdf3.head()
# Out:
#        date  tmax  tmin    prcp  year  month  day  precipitation
# 0  20030101  44.8    24   0.00G  2003      1    1           0.00
# 1  20030102  49.5    23   0.54G  2003      1    2           0.54
# 2  20030103  51.0    24   0.17G  2003      1    3           0.17
# 3  20030104  49.7    24   0.08G  2003      1    4           0.08
# 4  20030105  46.4    24   0.39G  2003      1    5           0.39

# %%
wdf4=wdf3[['year','month','day','tmax', 'tmin', 'precipitation']]

# %%
wdf_final=wdf4.copy()

# %%
new_df1=pd.merge(wdf_final,df_final, how='left', on=['year','month','day'])

# %%
cpi_df=pd.read_csv('data/consumer_price_index_nohead.csv')
cpi_df2=cpi_df.copy()

# %%
cpi_df2['year'] = cpi_df2.date.str.split('-').str.get(1)
cpi_df2['month'] = cpi_df2.date.str.split('-').str.get(0) 
cpi_df2.drop('date', axis=1,inplace=True)

# %%
import calendar
d=dict((v,k) for k,v in enumerate(calendar.month_abbr))
cpi_df2.month=cpi_df2.month.map(d)

cpi_df2.year='20'+ cpi_df2.year

# %%
cpi_df2=cpi_df2.apply(pd.to_numeric, errors='ignore')

# %%
new_df2=pd.merge(new_df1,cpi_df2, how='inner', on=['year','month'])

# %%
gdp_dftemp=pd.read_csv('data/gdp_2007dollars_nohead.csv')

# %%
gdp_df=gdp_dftemp.copy()

# %%
gdp_df['year'] = gdp_df.date.str.split('-').str.get(1)
gdp_df['month'] = gdp_df.date.str.split('-').str.get(0) 
gdp_df.drop('date', axis=1,inplace=True)

# %%
import calendar
d=dict((v,k) for k,v in enumerate(calendar.month_abbr))
gdp_df.month=gdp_df.month.map(d)

gdp_df.year='20'+ gdp_df.year

# %%
gdp_df=gdp_df.apply(pd.to_numeric, errors='ignore')

# %%
new_df3=pd.merge(new_df2,gdp_df, how='inner', on=['year','month'])

# %%
emp_df_init=pd.read_csv('data/employment_nohead.csv')
emp_df=emp_df_init.copy()

# %%
emp_df.head()
# Out:
#      date  seasonally_adjusted_unemployment  unadjusted_unemployment
# 0  Jan-03                               7.9                      7.5
# 1  Feb-03                               7.6                      7.5
# 2  Mar-03                               7.0                      7.2
# 3  Apr-03                               7.1                      7.1
# 4  May-03                               7.2                      7.1

# %%
emp_df['year'] = emp_df.date.str.split('-').str.get(1)
emp_df['month'] = emp_df.date.str.split('-').str.get(0) 
emp_df.drop('date', axis=1,inplace=True)

# %%
import calendar
d=dict((v,k) for k,v in enumerate(calendar.month_abbr))
emp_df.month=emp_df.month.map(d)

emp_df.year='20'+ emp_df.year

# %%
emp_df=emp_df.apply(pd.to_numeric, errors='ignore')

# %%
new_df4=pd.merge(new_df3,emp_df, how='inner', on=['year','month'])

# %%
drugs_init=pd.read_csv('data/drug_offences_2006_to_2016.csv')
drugs_init
# Out:
#     year  Total Drug violations   Possession, cocaine   Heroin, possession   \
# 0   2006                   25630                  4682                  515
# 1   2007                   28472                  4428                  378
# 2   2008                   27032                  3992                  389
# 3   2009                   23948                  2891                  347
# 4   2010                   26928                  2642                  316
# 5   2011                   27178                  2524                  379
# 6   2012                   25455                  2597                  508
# 7   2013                   26354                  2654                  617
# 8   2014                   24321                  2310                  853
# 9   2015                   22132                  2068                 1139
# 10  2016                   21507                  2047                 1550
#
#     Other Controlled Drugs and Substances Act, possession  \
# 0                                                1562
# 1                                                2265
# 2                                                1881
# 3                                                1079
# 4                                                1165
# 5                                                1196
# 6                                                1106
# 7                                                 997
# 8                                                1130
# 9                                                1278
# 10                                               1575
#
#     Methamphetamines (crystal meth), possession
# 0                                              1
# 1                                            306
# 2                                            334
# 3                                            310
# 4                                            429
# 5                                            539
# 6                                            663
# 7                                           1058
# 8                                           1549
# 9                                           1828
# 10                                          2153

# %%
drugs_init.columns
# Out:
# Index(['year', 'Total Drug violations ', 'Possession, cocaine ',
#        'Heroin, possession ',
#        'Other Controlled Drugs and Substances Act, possession',
#        'Methamphetamines (crystal meth), possession '],
#       dtype='object')

# %%
drugs_df=drugs_init.copy()

# %%
drugs_df2=drugs_df[['year','Possession, cocaine ',
       'Heroin, possession ',]]

# %%
drugs_df3=drugs_df2.copy()

# %%
drugs_df3.loc[11]=[2017, 2047,1550]

# %%
drugs_df3.loc[12]=[2003, 4682,515]
drugs_df3.loc[13]=[2004, 4682,515]
drugs_df3.loc[14]=[2005, 4682,515]
#drugs_df3['Average_Heroin4_Price']=['2003',191.3,141.1,261.6,2007',282.3,335.5,'2010',254.5,254.5,304.4,257.95,281.16,257.95,'2017']
#drugs_df3['Average_Cocaine_Price']=['2003','2004','2005','2006','2007',70.2,96.8,'2010',80.5,'2012','2013',86,'2015','2016','2017']

# %%
drugs_df3['Average_Heroin4_Price']=[210,191.3,141.1,261.6,271,282.3,335.5,298,254.5,254.5,304.4,257.95,281.16,257.95,245]

# %%
new_df5=pd.merge(new_df4,drugs_df3, how='inner', on=['year'])

# %%
new_df_final=new_df5.copy()

# %%
new_df_final.columns
# Out:
# Index(['year', 'month', 'day', 'tmax', 'tmin', 'precipitation', 'day_segment',
#        'neighborhood', 'number_of_crimes', 'consumer_price_index',
#        'gdp_millions_2007', 'seasonally_adjusted_unemployment',
#        'unadjusted_unemployment', 'Possession, cocaine ',
#        'Heroin, possession ', 'Average_Heroin4_Price'],
#       dtype='object')

# %%
new_df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206074 entries, 0 to 206073
# Data columns (total 16 columns):
# year                                206074 non-null int64
# month                               206074 non-null int64
# day                                 206074 non-null int64
# tmax                                206074 non-null float64
# tmin                                206074 non-null int64
# precipitation                       206074 non-null float64
# day_segment                         206074 non-null category
# neighborhood                        206074 non-null object
# number_of_crimes                    206074 non-null int64
# consumer_price_index                206074 non-null float64
# gdp_millions_2007                   206074 non-null int64
# seasonally_adjusted_unemployment    206074 non-null float64
# unadjusted_unemployment             206074 non-null float64
# Possession, cocaine                 206074 non-null int64
# Heroin, possession                  206074 non-null int64
# Average_Heroin4_Price               206074 non-null float64
# dtypes: category(1), float64(6), int64(8), object(1)
# memory usage: 25.4+ MB

# %%
new_df_final.apply(pd.to_numeric, errors='ignore')
# Out:
#         year  month  day  tmax  tmin  precipitation    day_segment  \
# 0       2003      1    1  44.8    24           0.00  1200am-0759am
# 1       2003      1    1  44.8    24           0.00  1200am-0759am
# 2       2003      1    1  44.8    24           0.00  1200am-0759am
# 3       2003      1    1  44.8    24           0.00  1200am-0759am
# 4       2003      1    1  44.8    24           0.00  1200am-0759am
# 5       2003      1    1  44.8    24           0.00  1200am-0759am
# 6       2003      1    1  44.8    24           0.00  1200am-0759am
# 7       2003      1    1  44.8    24           0.00  1200am-0759am
# 8       2003      1    1  44.8    24           0.00  1200am-0759am
# 9       2003      1    1  44.8    24           0.00  1200am-0759am
# 10      2003      1    1  44.8    24           0.00  1200am-0759am
# 11      2003      1    1  44.8    24           0.00  1200am-0759am
# 12      2003      1    1  44.8    24           0.00  1200am-0759am
# 13      2003      1    1  44.8    24           0.00  1200am-0759am
# 14      2003      1    1  44.8    24           0.00  1200am-0759am
# 15      2003      1    1  44.8    24           0.00  1200am-0759am
# 16      2003      1    1  44.8    24           0.00  1200am-0759am
# 17      2003      1    1  44.8    24           0.00  1200am-0759am
# 18      2003      1    1  44.8    24           0.00  0800am-0359pm
# 19      2003      1    1  44.8    24           0.00  0800am-0359pm
# 20      2003      1    1  44.8    24           0.00  0800am-0359pm
# 21      2003      1    1  44.8    24           0.00  0800am-0359pm
# 22      2003      1    1  44.8    24           0.00  0800am-0359pm
# 23      2003      1    1  44.8    24           0.00  0800am-0359pm
# 24      2003      1    1  44.8    24           0.00  0800am-0359pm
# 25      2003      1    1  44.8    24           0.00  0800am-0359pm
# 26      2003      1    1  44.8    24           0.00  0800am-0359pm
# 27      2003      1    1  44.8    24           0.00  0800am-0359pm
# 28      2003      1    1  44.8    24           0.00  0800am-0359pm
# 29      2003      1    1  44.8    24           0.00  0800am-0359pm
# ...      ...    ...  ...   ...   ...            ...            ...
# 206044  2017     12   31  30.2    24           0.01  1200am-0759am
# 206045  2017     12   31  30.2    24           0.01  1200am-0759am
# 206046  2017     12   31  30.2    24           0.01  1200am-0759am
# 206047  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206048  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206049  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206050  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206051  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206052  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206053  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206054  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206055  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206056  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206057  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206058  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206059  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206060  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206061  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206062  2017     12   31  30.2    24           0.01  0800am-0359pm
# 206063  2017     12   31  30.2    24           0.01  0400pm-1159pm
# 206064  2017     12   31  30.2    24           0.01  0400pm-1159pm
# 206065  2017     12   31  30.2    24           0.01  0400pm-1159pm
# 206066  2017     12   31  30.2    24           0.01  0400pm-1159pm
# 206067  2017     12   31  30.2    24           0.01  0400pm-1159pm
# 206068  2017     12   31  30.2    24           0.01  0400pm-1159pm
# 206069  2017     12   31  30.2    24           0.01  0400pm-1159pm
# 206070  2017     12   31  30.2    24           0.01  0400pm-1159pm
# 206071  2017     12   31  30.2    24           0.01  0400pm-1159pm
# 206072  2017     12   31  30.2    24           0.01  0400pm-1159pm
# 206073  2017     12   31  30.2    24           0.01  0400pm-1159pm
#
#                      neighborhood  number_of_crimes  consumer_price_index  \
# 0       Central Business District                14                 100.9
# 1               Dunbar-Southlands                 1                 100.9
# 2                        Fairview                 1                 100.9
# 3              Grandview-Woodland                 6                 100.9
# 4                Hastings-Sunrise                 3                 100.9
# 5        Kensington-Cedar Cottage                 3                 100.9
# 6                      Kerrisdale                 1                 100.9
# 7                       Killarney                 1                 100.9
# 8                       Kitsilano                 3                 100.9
# 9                         Marpole                 3                 100.9
# 10                 Mount Pleasant                 3                 100.9
# 11            Renfrew-Collingwood                 3                 100.9
# 12                     Riley Park                 2                 100.9
# 13                    Shaughnessy                 1                 100.9
# 14                     Strathcona                 2                 100.9
# 15                         Sunset                 2                 100.9
# 16            Victoria-Fraserview                 5                 100.9
# 17                       West End                 4                 100.9
# 18                  Arbutus Ridge                 1                 100.9
# 19      Central Business District                13                 100.9
# 20             Grandview-Woodland                 4                 100.9
# 21               Hastings-Sunrise                 1                 100.9
# 22       Kensington-Cedar Cottage                 4                 100.9
# 23                      Killarney                 1                 100.9
# 24                      Kitsilano                 1                 100.9
# 25                 Mount Pleasant                 5                 100.9
# 26            Renfrew-Collingwood                 3                 100.9
# 27                     Riley Park                 4                 100.9
# 28                   South Cambie                 4                 100.9
# 29                     Strathcona                 2                 100.9
# ...                           ...               ...                   ...
# 206044                 Strathcona                 1                 127.8
# 206045                     Sunset                 1                 127.8
# 206046        Victoria-Fraserview                 2                 127.8
# 206047              Arbutus Ridge                 1                 127.8
# 206048  Central Business District                13                 127.8
# 206049          Dunbar-Southlands                 1                 127.8
# 206050                   Fairview                 3                 127.8
# 206051         Grandview-Woodland                 2                 127.8
# 206052           Hastings-Sunrise                 1                 127.8
# 206053   Kensington-Cedar Cottage                 1                 127.8
# 206054                  Kitsilano                 1                 127.8
# 206055             Mount Pleasant                 4                 127.8
# 206056                   Oakridge                 2                 127.8
# 206057        Renfrew-Collingwood                 4                 127.8
# 206058                 Riley Park                 1                 127.8
# 206059                Shaughnessy                 1                 127.8
# 206060               Stanley Park                 1                 127.8
# 206061        Victoria-Fraserview                 1                 127.8
# 206062                   West End                 2                 127.8
# 206063              Arbutus Ridge                 1                 127.8
# 206064  Central Business District                17                 127.8
# 206065         Grandview-Woodland                 1                 127.8
# 206066                  Killarney                 3                 127.8
# 206067                  Kitsilano                 1                 127.8
# 206068             Mount Pleasant                 3                 127.8
# 206069        Renfrew-Collingwood                 2                 127.8
# 206070                Shaughnessy                 1                 127.8
# 206071                 Strathcona                 2                 127.8
# 206072                     Sunset                 3                 127.8
# 206073                   West End                 3                 127.8
#
#         gdp_millions_2007  seasonally_adjusted_unemployment  \
# 0                 1305716                               7.9
# 1                 1305716                               7.9
# 2                 1305716                               7.9
# 3                 1305716                               7.9
# 4                 1305716                               7.9
# 5                 1305716                               7.9
# 6                 1305716                               7.9
# 7                 1305716                               7.9
# 8                 1305716                               7.9
# 9                 1305716                               7.9
# 10                1305716                               7.9
# 11                1305716                               7.9
# 12                1305716                               7.9
# 13                1305716                               7.9
# 14                1305716                               7.9
# 15                1305716                               7.9
# 16                1305716                               7.9
# 17                1305716                               7.9
# 18                1305716                               7.9
# 19                1305716                               7.9
# 20                1305716                               7.9
# 21                1305716                               7.9
# 22                1305716                               7.9
# 23                1305716                               7.9
# 24                1305716                               7.9
# 25                1305716                               7.9
# 26                1305716                               7.9
# 27                1305716                               7.9
# 28                1305716                               7.9
# 29                1305716                               7.9
# ...                   ...                               ...
# 206044            1762455                               4.1
# 206045            1762455                               4.1
# 206046            1762455                               4.1
# 206047            1762455                               4.1
# 206048            1762455                               4.1
# 206049            1762455                               4.1
# 206050            1762455                               4.1
# 206051            1762455                               4.1
# 206052            1762455                               4.1
# 206053            1762455                               4.1
# 206054            1762455                               4.1
# 206055            1762455                               4.1
# 206056            1762455                               4.1
# 206057            1762455                               4.1
# 206058            1762455                               4.1
# 206059            1762455                               4.1
# 206060            1762455                               4.1
# 206061            1762455                               4.1
# 206062            1762455                               4.1
# 206063            1762455                               4.1
# 206064            1762455                               4.1
# 206065            1762455                               4.1
# 206066            1762455                               4.1
# 206067            1762455                               4.1
# 206068            1762455                               4.1
# 206069            1762455                               4.1
# 206070            1762455                               4.1
# 206071            1762455                               4.1
# 206072            1762455                               4.1
# 206073            1762455                               4.1
#
#         unadjusted_unemployment  Possession, cocaine   Heroin, possession   \
# 0                           7.5                  4682                  515
# 1                           7.5                  4682                  515
# 2                           7.5                  4682                  515
# 3                           7.5                  4682                  515
# 4                           7.5                  4682                  515
# 5                           7.5                  4682                  515
# 6                           7.5                  4682                  515
# 7                           7.5                  4682                  515
# 8                           7.5                  4682                  515
# 9                           7.5                  4682                  515
# 10                          7.5                  4682                  515
# 11                          7.5                  4682                  515
# 12                          7.5                  4682                  515
# 13                          7.5                  4682                  515
# 14                          7.5                  4682                  515
# 15                          7.5                  4682                  515
# 16                          7.5                  4682                  515
# 17                          7.5                  4682                  515
# 18                          7.5                  4682                  515
# 19                          7.5                  4682                  515
# 20                          7.5                  4682                  515
# 21                          7.5                  4682                  515
# 22                          7.5                  4682                  515
# 23                          7.5                  4682                  515
# 24                          7.5                  4682                  515
# 25                          7.5                  4682                  515
# 26                          7.5                  4682                  515
# 27                          7.5                  4682                  515
# 28                          7.5                  4682                  515
# 29                          7.5                  4682                  515
# ...                         ...                   ...                  ...
# 206044                      3.9                  2047                 1550
# 206045                      3.9                  2047                 1550
# 206046                      3.9                  2047                 1550
# 206047                      3.9                  2047                 1550
# 206048                      3.9                  2047                 1550
# 206049                      3.9                  2047                 1550
# 206050                      3.9                  2047                 1550
# 206051                      3.9                  2047                 1550
# 206052                      3.9                  2047                 1550
# 206053                      3.9                  2047                 1550
# 206054                      3.9                  2047                 1550
# 206055                      3.9                  2047                 1550
# 206056                      3.9                  2047                 1550
# 206057                      3.9                  2047                 1550
# 206058                      3.9                  2047                 1550
# 206059                      3.9                  2047                 1550
# 206060                      3.9                  2047                 1550
# 206061                      3.9                  2047                 1550
# 206062                      3.9                  2047                 1550
# 206063                      3.9                  2047                 1550
# 206064                      3.9                  2047                 1550
# 206065                      3.9                  2047                 1550
# 206066                      3.9                  2047                 1550
# 206067                      3.9                  2047                 1550
# 206068                      3.9                  2047                 1550
# 206069                      3.9                  2047                 1550
# 206070                      3.9                  2047                 1550
# 206071                      3.9                  2047                 1550
# 206072                      3.9                  2047                 1550
# 206073                      3.9                  2047                 1550
#
#         Average_Heroin4_Price
# 0                      281.16
# 1                      281.16
# 2                      281.16
# 3                      281.16
# 4                      281.16
# 5                      281.16
# 6                      281.16
# 7                      281.16
# 8                      281.16
# 9                      281.16
# 10                     281.16
# 11                     281.16
# 12                     281.16
# 13                     281.16
# 14                     281.16
# 15                     281.16
# 16                     281.16
# 17                     281.16
# 18                     281.16
# 19                     281.16
# 20                     281.16
# 21                     281.16
# 22                     281.16
# 23                     281.16
# 24                     281.16
# 25                     281.16
# 26                     281.16
# 27                     281.16
# 28                     281.16
# 29                     281.16
# ...                       ...
# 206044                 257.95
# 206045                 257.95
# 206046                 257.95
# 206047                 257.95
# 206048                 257.95
# 206049                 257.95
# 206050                 257.95
# 206051                 257.95
# 206052                 257.95
# 206053                 257.95
# 206054                 257.95
# 206055                 257.95
# 206056                 257.95
# 206057                 257.95
# 206058                 257.95
# 206059                 257.95
# 206060                 257.95
# 206061                 257.95
# 206062                 257.95
# 206063                 257.95
# 206064                 257.95
# 206065                 257.95
# 206066                 257.95
# 206067                 257.95
# 206068                 257.95
# 206069                 257.95
# 206070                 257.95
# 206071                 257.95
# 206072                 257.95
# 206073                 257.95
#
# [206074 rows x 16 columns]

# %%
new_df_final.neighborhood.unique()
# Out:
# array(['Central Business District', 'Dunbar-Southlands', 'Fairview',
#        'Grandview-Woodland', 'Hastings-Sunrise',
#        'Kensington-Cedar Cottage', 'Kerrisdale', 'Killarney', 'Kitsilano',
#        'Marpole', 'Mount Pleasant', 'Renfrew-Collingwood', 'Riley Park',
#        'Shaughnessy', 'Strathcona', 'Sunset', 'Victoria-Fraserview',
#        'West End', 'Arbutus Ridge', 'South Cambie', 'Oakridge',
#        'West Point Grey', 'Musqueam', 'Stanley Park'], dtype=object)

# %%
df_central_business_district=new_df_final.loc[new_df_final['neighborhood'] == 'Central Business District']

# %%
df_central_business_district.head()
# Out:
#     year  month  day  tmax  tmin  precipitation    day_segment  \
# 0   2003      1    1  44.8    24           0.00  1200am-0759am
# 19  2003      1    1  44.8    24           0.00  0800am-0359pm
# 32  2003      1    1  44.8    24           0.00  0400pm-1159pm
# 46  2003      1    2  49.5    23           0.54  1200am-0759am
# 61  2003      1    2  49.5    23           0.54  0800am-0359pm
#
#                  neighborhood  number_of_crimes  consumer_price_index  \
# 0   Central Business District                14                 100.9
# 19  Central Business District                13                 100.9
# 32  Central Business District                10                 100.9
# 46  Central Business District                 6                 100.9
# 61  Central Business District                15                 100.9
#
#     gdp_millions_2007  seasonally_adjusted_unemployment  \
# 0             1305716                               7.9
# 19            1305716                               7.9
# 32            1305716                               7.9
# 46            1305716                               7.9
# 61            1305716                               7.9
#
#     unadjusted_unemployment  Possession, cocaine   Heroin, possession   \
# 0                       7.5                  4682                  515
# 19                      7.5                  4682                  515
# 32                      7.5                  4682                  515
# 46                      7.5                  4682                  515
# 61                      7.5                  4682                  515
#
#     Average_Heroin4_Price
# 0                  281.16
# 19                 281.16
# 32                 281.16
# 46                 281.16
# 61                 281.16

# %%
day_segment_number=['day_segment']

# %%
df_central_business_district2=pd.get_dummies(df_central_business_district,columns=day_segment_number, drop_first=True)

# %%
df_central_business_district2.head()
# Out:
#     year  month  day  tmax  tmin  precipitation               neighborhood  \
# 0   2003      1    1  44.8    24           0.00  Central Business District
# 19  2003      1    1  44.8    24           0.00  Central Business District
# 32  2003      1    1  44.8    24           0.00  Central Business District
# 46  2003      1    2  49.5    23           0.54  Central Business District
# 61  2003      1    2  49.5    23           0.54  Central Business District
#
#     number_of_crimes  consumer_price_index  gdp_millions_2007  \
# 0                 14                 100.9            1305716
# 19                13                 100.9            1305716
# 32                10                 100.9            1305716
# 46                 6                 100.9            1305716
# 61                15                 100.9            1305716
#
#     seasonally_adjusted_unemployment  unadjusted_unemployment  \
# 0                                7.9                      7.5
# 19                               7.9                      7.5
# 32                               7.9                      7.5
# 46                               7.9                      7.5
# 61                               7.9                      7.5
#
#     Possession, cocaine   Heroin, possession   Average_Heroin4_Price  \
# 0                   4682                  515                 281.16
# 19                  4682                  515                 281.16
# 32                  4682                  515                 281.16
# 46                  4682                  515                 281.16
# 61                  4682                  515                 281.16
#
#     day_segment_0800am-0359pm  day_segment_0400pm-1159pm
# 0                           0                          0
# 19                          1                          0
# 32                          0                          1
# 46                          0                          0
# 61                          1                          0

# %%
df_central_business_district2.columns
# Out:
# Index(['year', 'month', 'day', 'tmax', 'tmin', 'precipitation', 'neighborhood',
#        'number_of_crimes', 'consumer_price_index', 'gdp_millions_2007',
#        'seasonally_adjusted_unemployment', 'unadjusted_unemployment',
#        'Possession, cocaine ', 'Heroin, possession ', 'Average_Heroin4_Price',
#        'day_segment_0800am-0359pm', 'day_segment_0400pm-1159pm'],
#       dtype='object')

# %%
X=df_central_business_district2[['year', 'month', 'day', 'tmax', 'tmin', 'precipitation',
     'consumer_price_index', 'gdp_millions_2007',
       'seasonally_adjusted_unemployment', 'unadjusted_unemployment',
       'Possession, cocaine ', 'Heroin, possession ',
       'day_segment_0800am-0359pm', 'day_segment_0400pm-1159pm']]

y=df_central_business_district2['number_of_crimes']

# %%
sns.distplot(df_central_business_district2['number_of_crimes'])
# Out:
# /Users/michaeljoyce/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df_central_business_district2['number_of_crimes'].mean()
# Out:
# 7.117643448910709

# %%
df_central_business_district2.describe()
# Out:
#                year         month           day          tmax          tmin  \
# count  16295.000000  16295.000000  16295.000000  16295.000000  16295.000000
# mean    2009.993925      6.524394     15.718257     50.684155     23.892544
# std        4.330084      3.448263      8.801493     10.139383      0.722894
# min     2003.000000      1.000000      1.000000     14.300000      8.000000
# 25%     2006.000000      4.000000      8.000000     43.800000     24.000000
# 50%     2010.000000      7.000000     16.000000     50.800000     24.000000
# 75%     2014.000000     10.000000     23.000000     58.900000     24.000000
# max     2017.000000     12.000000     31.000000     79.300000     24.000000
#
#        precipitation  number_of_crimes  consumer_price_index  \
# count   16295.000000      16295.000000          16295.000000
# mean        0.095170          7.117643            114.715305
# std         0.199507          5.254441              7.423391
# min         0.000000          1.000000            100.900000
# 25%         0.000000          4.000000            108.500000
# 50%         0.010000          7.000000            114.700000
# 75%         0.100000          9.000000            120.000000
# max         2.350000        471.000000            128.600000
#
#        gdp_millions_2007  seasonally_adjusted_unemployment  \
# count       1.629500e+04                      16295.000000
# mean        1.519628e+06                          5.979141
# std         1.226037e+05                          1.240101
# min         1.305168e+06                          3.500000
# 25%         1.433878e+06                          4.800000
# 50%         1.487497e+06                          6.200000
# 75%         1.636490e+06                          6.900000
# max         1.762455e+06                          8.300000
#
#        unadjusted_unemployment  Possession, cocaine   Heroin, possession   \
# count             16295.000000          16295.000000         16295.000000
# mean                  5.993612           3265.343971           673.705247
# std                   1.250095           1070.285525           401.277866
# min                   3.700000           2047.000000           316.000000
# 25%                   4.800000           2310.000000           379.000000
# 50%                   6.100000           2654.000000           515.000000
# 75%                   7.100000           4682.000000           853.000000
# max                   8.500000           4682.000000          1550.000000
#
#        Average_Heroin4_Price  day_segment_0800am-0359pm  \
# count            16295.00000               16295.000000
# mean               256.24222                   0.335195
# std                 45.97873                   0.472073
# min                141.10000                   0.000000
# 25%                245.00000                   0.000000
# 50%                257.95000                   0.000000
# 75%                282.30000                   1.000000
# max                335.50000                   1.000000
#
#        day_segment_0400pm-1159pm
# count               16295.000000
# mean                    0.335318
# std                     0.472116
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     1.000000
# max                     1.000000

# %%
df_central_business_district2.loc[df_central_business_district2['number_of_crimes']==471]
# Out:
#         year  month  day  tmax  tmin  precipitation  \
# 121067  2011      6   15  55.8    24           0.17
#
#                      neighborhood  number_of_crimes  consumer_price_index  \
# 121067  Central Business District               471                 117.5
#
#         gdp_millions_2007  seasonally_adjusted_unemployment  \
# 121067            1522085                               7.3
#
#         unadjusted_unemployment  Possession, cocaine   Heroin, possession   \
# 121067                      7.4                  2524                  379
#
#         Average_Heroin4_Price  day_segment_0800am-0359pm  \
# 121067                  282.3                          0
#
#         day_segment_0400pm-1159pm
# 121067                          1

# %%
#remove outlier from 2011 riot
df_central_business_district2.loc[121067, 'number_of_crimes']=7

# %%
df_central_business_district2.describe()
# Out:
#                year         month           day          tmax          tmin  \
# count  16295.000000  16295.000000  16295.000000  16295.000000  16295.000000
# mean    2009.993925      6.524394     15.718257     50.684155     23.892544
# std        4.330084      3.448263      8.801493     10.139383      0.722894
# min     2003.000000      1.000000      1.000000     14.300000      8.000000
# 25%     2006.000000      4.000000      8.000000     43.800000     24.000000
# 50%     2010.000000      7.000000     16.000000     50.800000     24.000000
# 75%     2014.000000     10.000000     23.000000     58.900000     24.000000
# max     2017.000000     12.000000     31.000000     79.300000     24.000000
#
#        precipitation  number_of_crimes  consumer_price_index  \
# count   16295.000000      16295.000000          16295.000000
# mean        0.095170          7.089168            114.715305
# std         0.199507          3.794974              7.423391
# min         0.000000          1.000000            100.900000
# 25%         0.000000          4.000000            108.500000
# 50%         0.010000          7.000000            114.700000
# 75%         0.100000          9.000000            120.000000
# max         2.350000         44.000000            128.600000
#
#        gdp_millions_2007  seasonally_adjusted_unemployment  \
# count       1.629500e+04                      16295.000000
# mean        1.519628e+06                          5.979141
# std         1.226037e+05                          1.240101
# min         1.305168e+06                          3.500000
# 25%         1.433878e+06                          4.800000
# 50%         1.487497e+06                          6.200000
# 75%         1.636490e+06                          6.900000
# max         1.762455e+06                          8.300000
#
#        unadjusted_unemployment  Possession, cocaine   Heroin, possession   \
# count             16295.000000          16295.000000         16295.000000
# mean                  5.993612           3265.343971           673.705247
# std                   1.250095           1070.285525           401.277866
# min                   3.700000           2047.000000           316.000000
# 25%                   4.800000           2310.000000           379.000000
# 50%                   6.100000           2654.000000           515.000000
# 75%                   7.100000           4682.000000           853.000000
# max                   8.500000           4682.000000          1550.000000
#
#        Average_Heroin4_Price  day_segment_0800am-0359pm  \
# count            16295.00000               16295.000000
# mean               256.24222                   0.335195
# std                 45.97873                   0.472073
# min                141.10000                   0.000000
# 25%                245.00000                   0.000000
# 50%                257.95000                   0.000000
# 75%                282.30000                   1.000000
# max                335.50000                   1.000000
#
#        day_segment_0400pm-1159pm
# count               16295.000000
# mean                    0.335318
# std                     0.472116
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     1.000000
# max                     1.000000

# %%
df_central_business_district2.drop('neighborhood', axis=1)
# Out:
#         year  month  day  tmax  tmin  precipitation  number_of_crimes  \
# 0       2003      1    1  44.8    24           0.00                14
# 19      2003      1    1  44.8    24           0.00                13
# 32      2003      1    1  44.8    24           0.00                10
# 46      2003      1    2  49.5    23           0.54                 6
# 61      2003      1    2  49.5    23           0.54                15
# 75      2003      1    2  49.5    23           0.54                15
# 92      2003      1    3  51.0    24           0.17                 4
# 105     2003      1    3  51.0    24           0.17                11
# 122     2003      1    3  51.0    24           0.17                19
# 139     2003      1    4  49.7    24           0.08                 8
# 153     2003      1    4  49.7    24           0.08                14
# 166     2003      1    4  49.7    24           0.08                 8
# 183     2003      1    5  46.4    24           0.39                14
# 195     2003      1    5  46.4    24           0.39                 8
# 204     2003      1    5  46.4    24           0.39                 8
# 220     2003      1    6  38.7    23           0.00                 3
# 233     2003      1    6  38.7    23           0.00                13
# 248     2003      1    6  38.7    23           0.00                19
# 267     2003      1    7  38.5    24           0.00                 6
# 281     2003      1    7  38.5    24           0.00                11
# 299     2003      1    7  38.5    24           0.00                14
# 316     2003      1    8  40.9    21           0.00                 7
# 328     2003      1    8  40.9    21           0.00                13
# 344     2003      1    8  40.9    21           0.00                11
# 361     2003      1    9  47.8    24           0.01                 4
# 375     2003      1    9  47.8    24           0.01                 8
# 390     2003      1    9  47.8    24           0.01                 7
# 406     2003      1   10  36.5    24           0.00                11
# 418     2003      1   10  36.5    24           0.00                10
# 431     2003      1   10  36.5    24           0.00                20
# ...      ...    ...  ...   ...   ...            ...               ...
# 205738  2017     12   22  34.2    24           0.00                 6
# 205747  2017     12   22  34.2    24           0.00                 4
# 205763  2017     12   22  34.2    24           0.00                 7
# 205778  2017     12   23  30.6    24           0.00                 4
# 205786  2017     12   23  30.6    24           0.00                 6
# 205797  2017     12   23  30.6    24           0.00                11
# 205808  2017     12   24  28.0    24           0.00                 4
# 205814  2017     12   24  28.0    24           0.00                10
# 205823  2017     12   24  28.0    24           0.00                 9
# 205835  2017     12   25  30.9    24           0.00                 2
# 205848  2017     12   25  30.9    24           0.00                 5
# 205855  2017     12   25  30.9    24           0.00                11
# 205868  2017     12   26  29.6    24           0.00                10
# 205879  2017     12   26  29.6    24           0.00                10
# 205892  2017     12   26  29.6    24           0.00                16
# 205905  2017     12   27  28.8    24           0.00                 6
# 205915  2017     12   27  28.8    24           0.00                12
# 205925  2017     12   27  28.8    24           0.00                 9
# 205938  2017     12   28  33.7    24           0.16                 6
# 205947  2017     12   28  33.7    24           0.16                 8
# 205957  2017     12   28  33.7    24           0.16                 8
# 205969  2017     12   29  37.0    24           0.31                 4
# 205979  2017     12   29  37.0    24           0.31                 7
# 205991  2017     12   29  37.0    24           0.31                12
# 206002  2017     12   30  38.1    24           0.72                 3
# 206011  2017     12   30  38.1    24           0.72                10
# 206021  2017     12   30  38.1    24           0.72                 7
# 206036  2017     12   31  30.2    24           0.01                 3
# 206048  2017     12   31  30.2    24           0.01                13
# 206064  2017     12   31  30.2    24           0.01                17
#
#         consumer_price_index  gdp_millions_2007  \
# 0                      100.9            1305716
# 19                     100.9            1305716
# 32                     100.9            1305716
# 46                     100.9            1305716
# 61                     100.9            1305716
# 75                     100.9            1305716
# 92                     100.9            1305716
# 105                    100.9            1305716
# 122                    100.9            1305716
# 139                    100.9            1305716
# 153                    100.9            1305716
# 166                    100.9            1305716
# 183                    100.9            1305716
# 195                    100.9            1305716
# 204                    100.9            1305716
# 220                    100.9            1305716
# 233                    100.9            1305716
# 248                    100.9            1305716
# 267                    100.9            1305716
# 281                    100.9            1305716
# 299                    100.9            1305716
# 316                    100.9            1305716
# 328                    100.9            1305716
# 344                    100.9            1305716
# 361                    100.9            1305716
# 375                    100.9            1305716
# 390                    100.9            1305716
# 406                    100.9            1305716
# 418                    100.9            1305716
# 431                    100.9            1305716
# ...                      ...                ...
# 205738                 127.8            1762455
# 205747                 127.8            1762455
# 205763                 127.8            1762455
# 205778                 127.8            1762455
# 205786                 127.8            1762455
# 205797                 127.8            1762455
# 205808                 127.8            1762455
# 205814                 127.8            1762455
# 205823                 127.8            1762455
# 205835                 127.8            1762455
# 205848                 127.8            1762455
# 205855                 127.8            1762455
# 205868                 127.8            1762455
# 205879                 127.8            1762455
# 205892                 127.8            1762455
# 205905                 127.8            1762455
# 205915                 127.8            1762455
# 205925                 127.8            1762455
# 205938                 127.8            1762455
# 205947                 127.8            1762455
# 205957                 127.8            1762455
# 205969                 127.8            1762455
# 205979                 127.8            1762455
# 205991                 127.8            1762455
# 206002                 127.8            1762455
# 206011                 127.8            1762455
# 206021                 127.8            1762455
# 206036                 127.8            1762455
# 206048                 127.8            1762455
# 206064                 127.8            1762455
#
#         seasonally_adjusted_unemployment  unadjusted_unemployment  \
# 0                                    7.9                      7.5
# 19                                   7.9                      7.5
# 32                                   7.9                      7.5
# 46                                   7.9                      7.5
# 61                                   7.9                      7.5
# 75                                   7.9                      7.5
# 92                                   7.9                      7.5
# 105                                  7.9                      7.5
# 122                                  7.9                      7.5
# 139                                  7.9                      7.5
# 153                                  7.9                      7.5
# 166                                  7.9                      7.5
# 183                                  7.9                      7.5
# 195                                  7.9                      7.5
# 204                                  7.9                      7.5
# 220                                  7.9                      7.5
# 233                                  7.9                      7.5
# 248                                  7.9                      7.5
# 267                                  7.9                      7.5
# 281                                  7.9                      7.5
# 299                                  7.9                      7.5
# 316                                  7.9                      7.5
# 328                                  7.9                      7.5
# 344                                  7.9                      7.5
# 361                                  7.9                      7.5
# 375                                  7.9                      7.5
# 390                                  7.9                      7.5
# 406                                  7.9                      7.5
# 418                                  7.9                      7.5
# 431                                  7.9                      7.5
# ...                                  ...                      ...
# 205738                               4.1                      3.9
# 205747                               4.1                      3.9
# 205763                               4.1                      3.9
# 205778                               4.1                      3.9
# 205786                               4.1                      3.9
# 205797                               4.1                      3.9
# 205808                               4.1                      3.9
# 205814                               4.1                      3.9
# 205823                               4.1                      3.9
# 205835                               4.1                      3.9
# 205848                               4.1                      3.9
# 205855                               4.1                      3.9
# 205868                               4.1                      3.9
# 205879                               4.1                      3.9
# 205892                               4.1                      3.9
# 205905                               4.1                      3.9
# 205915                               4.1                      3.9
# 205925                               4.1                      3.9
# 205938                               4.1                      3.9
# 205947                               4.1                      3.9
# 205957                               4.1                      3.9
# 205969                               4.1                      3.9
# 205979                               4.1                      3.9
# 205991                               4.1                      3.9
# 206002                               4.1                      3.9
# 206011                               4.1                      3.9
# 206021                               4.1                      3.9
# 206036                               4.1                      3.9
# 206048                               4.1                      3.9
# 206064                               4.1                      3.9
#
#         Possession, cocaine   Heroin, possession   Average_Heroin4_Price  \
# 0                       4682                  515                 281.16
# 19                      4682                  515                 281.16
# 32                      4682                  515                 281.16
# 46                      4682                  515                 281.16
# 61                      4682                  515                 281.16
# 75                      4682                  515                 281.16
# 92                      4682                  515                 281.16
# 105                     4682                  515                 281.16
# 122                     4682                  515                 281.16
# 139                     4682                  515                 281.16
# 153                     4682                  515                 281.16
# 166                     4682                  515                 281.16
# 183                     4682                  515                 281.16
# 195                     4682                  515                 281.16
# 204                     4682                  515                 281.16
# 220                     4682                  515                 281.16
# 233                     4682                  515                 281.16
# 248                     4682                  515                 281.16
# 267                     4682                  515                 281.16
# 281                     4682                  515                 281.16
# 299                     4682                  515                 281.16
# 316                     4682                  515                 281.16
# 328                     4682                  515                 281.16
# 344                     4682                  515                 281.16
# 361                     4682                  515                 281.16
# 375                     4682                  515                 281.16
# 390                     4682                  515                 281.16
# 406                     4682                  515                 281.16
# 418                     4682                  515                 281.16
# 431                     4682                  515                 281.16
# ...                      ...                  ...                    ...
# 205738                  2047                 1550                 257.95
# 205747                  2047                 1550                 257.95
# 205763                  2047                 1550                 257.95
# 205778                  2047                 1550                 257.95
# 205786                  2047                 1550                 257.95
# 205797                  2047                 1550                 257.95
# 205808                  2047                 1550                 257.95
# 205814                  2047                 1550                 257.95
# 205823                  2047                 1550                 257.95
# 205835                  2047                 1550                 257.95
# 205848                  2047                 1550                 257.95
# 205855                  2047                 1550                 257.95
# 205868                  2047                 1550                 257.95
# 205879                  2047                 1550                 257.95
# 205892                  2047                 1550                 257.95
# 205905                  2047                 1550                 257.95
# 205915                  2047                 1550                 257.95
# 205925                  2047                 1550                 257.95
# 205938                  2047                 1550                 257.95
# 205947                  2047                 1550                 257.95
# 205957                  2047                 1550                 257.95
# 205969                  2047                 1550                 257.95
# 205979                  2047                 1550                 257.95
# 205991                  2047                 1550                 257.95
# 206002                  2047                 1550                 257.95
# 206011                  2047                 1550                 257.95
# 206021                  2047                 1550                 257.95
# 206036                  2047                 1550                 257.95
# 206048                  2047                 1550                 257.95
# 206064                  2047                 1550                 257.95
#
#         day_segment_0800am-0359pm  day_segment_0400pm-1159pm
# 0                               0                          0
# 19                              1                          0
# 32                              0                          1
# 46                              0                          0
# 61                              1                          0
# 75                              0                          1
# 92                              0                          0
# 105                             1                          0
# 122                             0                          1
# 139                             0                          0
# 153                             1                          0
# 166                             0                          1
# 183                             0                          0
# 195                             1                          0
# 204                             0                          1
# 220                             0                          0
# 233                             1                          0
# 248                             0                          1
# 267                             0                          0
# 281                             1                          0
# 299                             0                          1
# 316                             0                          0
# 328                             1                          0
# 344                             0                          1
# 361                             0                          0
# 375                             1                          0
# 390                             0                          1
# 406                             0                          0
# 418                             1                          0
# 431                             0                          1
# ...                           ...                        ...
# 205738                          0                          0
# 205747                          1                          0
# 205763                          0                          1
# 205778                          0                          0
# 205786                          1                          0
# 205797                          0                          1
# 205808                          0                          0
# 205814                          1                          0
# 205823                          0                          1
# 205835                          0                          0
# 205848                          1                          0
# 205855                          0                          1
# 205868                          0                          0
# 205879                          1                          0
# 205892                          0                          1
# 205905                          0                          0
# 205915                          1                          0
# 205925                          0                          1
# 205938                          0                          0
# 205947                          1                          0
# 205957                          0                          1
# 205969                          0                          0
# 205979                          1                          0
# 205991                          0                          1
# 206002                          0                          0
# 206011                          1                          0
# 206021                          0                          1
# 206036                          0                          0
# 206048                          1                          0
# 206064                          0                          1
#
# [16295 rows x 16 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)  # Don't cheat - fit only on training data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)  # apply same transformation to test data

# %%
#sns.heatmap(df_central_business_district2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(lm.intercept_)
# Out:
# 7.10108714712

# %%
coeff_df=pd.DataFrame(lm.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#                                   Coefficient
# year                                -0.910114
# month                                0.090485
# day                                 -0.285756
# tmax                                 0.276981
# tmin                                -0.010798
# precipitation                       -0.031398
# consumer_price_index                -0.124907
# gdp_millions_2007                   -1.174742
# seasonally_adjusted_unemployment    -0.852296
# unadjusted_unemployment              0.173349
# Possession, cocaine                 -0.700418
# Heroin, possession                   1.841322
# day_segment_0800am-0359pm            1.332170
# day_segment_0400pm-1159pm            1.600127

# %%
from sklearn import metrics
predictions=lm.predict(X_test)

# %%
plt.scatter(y_test, predictions)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 2.51517527411
# MSE: 10.6814561517
# RMSE: 3.26824970767

# %%
from sklearn.metrics import r2_score
r2_score(y_test,predictions)
# Out:
# 0.27241150735752795

# %%
from sklearn import linear_model
clf=linear_model.Lasso(alpha=0.1)
clf.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
print(clf.coef_)
# Out:
# [-0.          0.         -0.18307589  0.19027314 -0.         -0.         -0.
#  -0.12708007 -0.11366492 -0.          0.81832776  1.19889567  1.12621562
#   1.39436664]

# %%
print(clf.intercept_)
# Out:
# 7.10108714712

# %%
coeff_df=pd.DataFrame(clf.coef_, X.columns, columns=['Coefficeint'])
coeff_df
# Out:
#                                   Coefficeint
# year                                -0.000000
# month                                0.000000
# day                                 -0.183076
# tmax                                 0.190273
# tmin                                -0.000000
# precipitation                       -0.000000
# consumer_price_index                -0.000000
# gdp_millions_2007                   -0.127080
# seasonally_adjusted_unemployment    -0.113665
# unadjusted_unemployment             -0.000000
# Possession, cocaine                  0.818328
# Heroin, possession                   1.198896
# day_segment_0800am-0359pm            1.126216
# day_segment_0400pm-1159pm            1.394367

# %%
predictions2=clf.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions2))
print('MSE:', metrics.mean_squared_error(y_test, predictions2))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions2)))
# Out:
# MAE: 2.54727437528
# MSE: 10.9165113172
# RMSE: 3.30401442448

# %%
r2_score(y_test,predictions2)
# Out:
# 0.25640026028210816

# %%
from sklearn.ensemble import RandomForestRegressor

regr=RandomForestRegressor(max_depth=2, random_state=42)
regr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
predictions3=regr.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions3))
print('MSE:', metrics.mean_squared_error(y_test, predictions3))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions3)))
# Out:
# MAE: 2.71963062577
# MSE: 12.1309415903
# RMSE: 3.48295012744

# %%
r2_score(y_test,predictions3)
# Out:
# 0.17367694248115273

# %%
# from sklearn.grid_search import GridSearchCV


# param_dist = {"n_estimators":[10, 25, 50, 100],
#               "max_depth": [2, 5, 10, 30, 50],
#               "max_features": [3,4,5]}
              
# grid=GridSearchCV(regr,param_dist)
# grid.fit(X_train, y_train)

# %%
estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
           max_features='auto', max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=1, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
           oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
estimator.fit(X_train, y_train)

predictions4 = estimator.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions4))
print('MSE:', metrics.mean_squared_error(y_test, predictions4))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions4)))
# Out:
# MAE: 2.71963062577
# MSE: 12.1309415903
# RMSE: 3.48295012744

# %%
r2_score(y_test,predictions4)
# Out:
# 0.17367694248115273

# %%
# from sklearn.grid_search import GridSearchCV


# param_dist = {"n_estimators":[10, 25, 50, 100,200,500],
#               "max_depth": [2,3,4,5, 10, 25, 50, 100],
#               "max_features": [3,4,5,7, 10,20]}
              
# grid=GridSearchCV(regr,param_dist)
# grid.fit(X_train, y_train)

# %%
estimator5=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
           max_features='auto', max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=1, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
           oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
estimator5.fit(X_train, y_train)

predictions5 = estimator5.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions5))
print('MSE:', metrics.mean_squared_error(y_test, predictions5))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions5)))
# Out:
# MAE: 2.71963062577
# MSE: 12.1309415903
# RMSE: 3.48295012744

# %%
r2_score(y_test,predictions5)
# Out:
# 0.17367694248115273

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
# ada=AdaBoostRegressor()
# from sklearn.grid_search import GridSearchCV


# param_dist = {"n_estimators":[10, 25, 50, 100],
#               "learning_rate": [1,0.5,0.1,0.05,0.01],
#               "random_state": [42]}
              
# grid=GridSearchCV(ada,param_dist)
# grid.fit(X_train, y_train)

# %%
estimator6=AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
         n_estimators=50, random_state=None)

# %%
estimator6.fit(X_train, y_train)

predictions6 = estimator6.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions6))
print('MSE:', metrics.mean_squared_error(y_test, predictions6))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions6)))
# Out:
# MAE: 2.97391700144
# MSE: 13.3169429687
# RMSE: 3.64923868344

# %%
r2_score(y_test,predictions5)
# Out:
# 0.17367694248115273

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgdr=SGDRegressor(shuffle=True)
sgdr.fit(X_train,y_train)
# Out:
# /Users/michaeljoyce/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# SGDRegressor(alpha=0.0001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', max_iter=None, n_iter=None, penalty='l2',
#        power_t=0.25, random_state=None, shuffle=True, tol=None, verbose=0,
#        warm_start=False)

# %%
predictions7=sgdr.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions7))
print('MSE:', metrics.mean_squared_error(y_test, predictions7))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions7)))
# Out:
# MAE: 2.51662046892
# MSE: 10.7126463909
# RMSE: 3.27301793318

# %%
r2_score(y_test,predictions7)
# Out:
# 0.27028692257903897

# %%
sgdr.get_params()
# Out:
# {'alpha': 0.0001,
#  'average': False,
#  'epsilon': 0.1,
#  'eta0': 0.01,
#  'fit_intercept': True,
#  'l1_ratio': 0.15,
#  'learning_rate': 'invscaling',
#  'loss': 'squared_loss',
#  'max_iter': None,
#  'n_iter': None,
#  'penalty': 'l2',
#  'power_t': 0.25,
#  'random_state': None,
#  'shuffle': True,
#  'tol': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
#  from sklearn.grid_search import GridSearchCV



# param_dist = {"alpha":[0.01,0.001,0.001],
#               'epsilon':[0.2,0.1,0.05,0.01],
#               "loss": ['squared_loss','huber','epsilon_insensitive'],
#               "penalty": ['l2','l1','elasticnet'],
#              "average":[True, False]}
              
# grid=GridSearchCV(sgdr,param_dist)
# grid.fit(X_train, y_train)

# %%
estimator8=SGDRegressor(alpha=0.0001, average=False, epsilon=0.1, eta0=0.01,
       fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
       loss='squared_loss', max_iter=None, n_iter=None, penalty='l2',
       power_t=0.25, random_state=None, shuffle=True, tol=None, verbose=0,
       warm_start=False)

# %%
estimator8.fit(X_train, y_train)

predictions8 = estimator8.predict(X_test)
# Out:
# /Users/michaeljoyce/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions8))
print('MSE:', metrics.mean_squared_error(y_test, predictions8))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions8)))
# Out:
# MAE: 2.53137212449
# MSE: 10.7379040648
# RMSE: 3.27687413014

# %%
r2_score(y_test,predictions8)
# Out:
# 0.26856644621298353

# %%
from sklearn.linear_model import ElasticNetCV

# %%
elan=ElasticNetCV(normalize=False)

# %%
elan.fit(X_train,y_train)
# Out:
# ElasticNetCV(alphas=None, copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#        l1_ratio=0.5, max_iter=1000, n_alphas=100, n_jobs=1,
#        normalize=False, positive=False, precompute='auto',
#        random_state=None, selection='cyclic', tol=0.0001, verbose=0)

# %%
predictions9=elan.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions9))
print('MSE:', metrics.mean_squared_error(y_test, predictions9))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions9)))
# Out:
# MAE: 2.51498898875
# MSE: 10.6787513986
# RMSE: 3.26783588918

# %%
r2_score(y_test,predictions9)
# Out:
# 0.27259574695418698

# %%
from sklearn.linear_model import BayesianRidge

# %%
br = BayesianRidge(normalize=False)
br.fit(X_train,y_train)
# Out:
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)

# %%
predictions10=br.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, predictions10))
print('MSE:', metrics.mean_squared_error(y_test, predictions10))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions10)))
# Out:
# MAE: 2.51507389056
# MSE: 10.6809985534
# RMSE: 3.26817970029

# %%
r2_score(y_test,predictions10)
# Out:
# 0.27244267756871177

# %%
# from sklearn.grid_search import GridSearchCV
# br = BayesianRidge(normalize=False)

# param_dist = {"n_iter":[100,300,500,1000]}
              
# grid=GridSearchCV(sgdr,param_dist)
# grid.fit(X_train, y_train)

# %%
estimator11=SGDRegressor(alpha=0.0001, average=False, epsilon=0.1, eta0=0.01,
       fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
       loss='squared_loss', max_iter=None, n_iter=None, penalty='l2',
       power_t=0.25, random_state=None, shuffle=True, tol=None, verbose=0,
       warm_start=False)

estimator11.fit(X_train, y_train)

predictions11 = estimator11.predict(X_test)
# Out:
# /Users/michaeljoyce/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions11))
print('MSE:', metrics.mean_squared_error(y_test, predictions11))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions11)))
# Out:
# MAE: 2.52352342738
# MSE: 10.7741655735
# RMSE: 3.28240240884

# %%
r2_score(y_test,predictions11)
# Out:
# 0.2660964218905798

# %%
from sklearn.ensemble import BaggingRegressor
bagreg=BaggingRegressor()
bagreg.fit(X_train,y_train)
# Out:
# BaggingRegressor(base_estimator=None, bootstrap=True,
#          bootstrap_features=False, max_features=1.0, max_samples=1.0,
#          n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#          verbose=0, warm_start=False)

# %%
predictions12=bagreg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, predictions12))
print('MSE:', metrics.mean_squared_error(y_test, predictions12))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions12)))
# Out:
# MAE: 2.61476784619
# MSE: 11.5821394968
# RMSE: 3.40325425098

# %%
r2_score(y_test,predictions12)
# Out:
# 0.21105968152484034
