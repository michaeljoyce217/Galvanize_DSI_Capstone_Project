# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data/crime_csv_all_years.csv',parse_dates={'dttime':[1,2,3]}, keep_date_col=True)
df.head()
# Out:
#       dttime                        TYPE  YEAR MONTH DAY  HOUR  MINUTE  \
# 0 2003-11-23          Theft from Vehicle  2003    11  23   0.0     1.0
# 1 2003-05-09          Theft from Vehicle  2003     5   9  18.0     0.0
# 2 2003-03-09    Offence Against a Person  2003     3   9   NaN     NaN
# 3 2003-01-20    Offence Against a Person  2003     1  20   NaN     NaN
# 4 2003-02-07  Break and Enter Commercial  2003     2   7   0.0    30.0
#
#                HUNDRED_BLOCK              NEIGHBOURHOOD          X           Y
# 0          13XX W GEORGIA ST  Central Business District  490745.08  5459529.81
# 1             30XX W 8TH AVE                  Kitsilano  487465.51  5456929.11
# 2  OFFSET TO PROTECT PRIVACY                        NaN       0.00        0.00
# 3  OFFSET TO PROTECT PRIVACY                        NaN       0.00        0.00
# 4           71XX VICTORIA DR        Victoria-Fraserview  495196.35  5451832.55

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549774 entries, 0 to 549773
# Data columns (total 11 columns):
# dttime           549774 non-null datetime64[ns]
# TYPE             549774 non-null object
# YEAR             549774 non-null object
# MONTH            549774 non-null object
# DAY              549774 non-null object
# HOUR             493779 non-null float64
# MINUTE           493779 non-null float64
# HUNDRED_BLOCK    549761 non-null object
# NEIGHBOURHOOD    491472 non-null object
# X                549774 non-null float64
# Y                549774 non-null float64
# dtypes: datetime64[ns](1), float64(4), object(6)
# memory usage: 46.1+ MB

# %%
df['day_of_week']=df['dttime'].dt.weekday_name

# %%
df_temp=df.copy()

# %%
df_temp.head()
# Out:
#       dttime                        TYPE  YEAR MONTH DAY  HOUR  MINUTE  \
# 0 2003-11-23          Theft from Vehicle  2003    11  23   0.0     1.0
# 1 2003-05-09          Theft from Vehicle  2003     5   9  18.0     0.0
# 2 2003-03-09    Offence Against a Person  2003     3   9   NaN     NaN
# 3 2003-01-20    Offence Against a Person  2003     1  20   NaN     NaN
# 4 2003-02-07  Break and Enter Commercial  2003     2   7   0.0    30.0
#
#                HUNDRED_BLOCK              NEIGHBOURHOOD          X  \
# 0          13XX W GEORGIA ST  Central Business District  490745.08
# 1             30XX W 8TH AVE                  Kitsilano  487465.51
# 2  OFFSET TO PROTECT PRIVACY                        NaN       0.00
# 3  OFFSET TO PROTECT PRIVACY                        NaN       0.00
# 4           71XX VICTORIA DR        Victoria-Fraserview  495196.35
#
#             Y day_of_week
# 0  5459529.81      Sunday
# 1  5456929.11      Friday
# 2        0.00      Sunday
# 3        0.00      Monday
# 4  5451832.55      Friday

# %%
df2=df_temp.dropna()
#remove missing data, all (or nearly all) of which is the non-property crime data

# %%
df3=df2.rename(index=str, columns={"YEAR": "year", "MONTH": "month", "DAY":"day","HOUR":"hour", "MINUTE":"minute", "NEIGHBOURHOOD":"neighborhood"})
#rename columns as all caps is annoying

# %%
df3.head()
# Out:
#       dttime                        TYPE  year month day  hour  minute  \
# 0 2003-11-23          Theft from Vehicle  2003    11  23   0.0     1.0
# 1 2003-05-09          Theft from Vehicle  2003     5   9  18.0     0.0
# 4 2003-02-07  Break and Enter Commercial  2003     2   7   0.0    30.0
# 5 2003-06-02  Break and Enter Commercial  2003     6   2   3.0     4.0
# 6 2003-12-31                    Mischief  2003    12  31   8.0    40.0
#
#        HUNDRED_BLOCK               neighborhood          X           Y  \
# 0  13XX W GEORGIA ST  Central Business District  490745.08  5459529.81
# 1     30XX W 8TH AVE                  Kitsilano  487465.51  5456929.11
# 4   71XX VICTORIA DR        Victoria-Fraserview  495196.35  5451832.55
# 5   71XX VICTORIA DR        Victoria-Fraserview  495196.35  5451832.55
# 6  10XX W GEORGIA ST                   West End  491128.32  5459137.86
#
#   day_of_week
# 0      Sunday
# 1      Friday
# 4      Friday
# 5      Monday
# 6   Wednesday

# %%
df4=df3.sort_values(['year','month','day','hour','minute'])
#sort by date

# %%
df5=df4.drop(['minute', 'HUNDRED_BLOCK','TYPE'], axis=1)
#remove extraneous data

# %%
df6=df5.apply(pd.to_numeric, errors='ignore')

# %%
#bin by 12am-8am, 8am-4pm, 4pm -12am
hourbins = [-0.1,8.0,16.0,24.1]
hourlabels = ['1200am-0759am', '0800am-0359pm', '0400pm-1159pm']
df6['day_segment'] = pd.cut(df6["hour"], bins=hourbins,labels=hourlabels)

# %%
df7=df6[['year', 'month', 'day', 'day_segment', 'neighborhood']]
#group by neighborhood, by day_segment

# %%
df7.head()
# Out:
#        year  month  day    day_segment               neighborhood
# 2148   2003      1    1  1200am-0759am  Central Business District
# 3215   2003      1    1  1200am-0759am  Central Business District
# 7453   2003      1    1  1200am-0759am                  Kitsilano
# 18527  2003      1    1  1200am-0759am         Grandview-Woodland
# 32204  2003      1    1  1200am-0759am  Central Business District

# %%
df8=df7.groupby(df7.columns.tolist()).size()

# %%
df8.head()
# Out:
# year  month  day  day_segment    neighborhood
# 2003  1      1    1200am-0759am  Central Business District    14
#                                  Dunbar-Southlands             1
#                                  Fairview                      1
#                                  Grandview-Woodland            6
#                                  Hastings-Sunrise              3
# dtype: int64

# %%
df9=pd.DataFrame(df8).reset_index()

# %%
df9.head()
# Out:
#    year  month  day    day_segment               neighborhood   0
# 0  2003      1    1  1200am-0759am  Central Business District  14
# 1  2003      1    1  1200am-0759am          Dunbar-Southlands   1
# 2  2003      1    1  1200am-0759am                   Fairview   1
# 3  2003      1    1  1200am-0759am         Grandview-Woodland   6
# 4  2003      1    1  1200am-0759am           Hastings-Sunrise   3

# %%
df10=df9.rename(index=str, columns={ 0 :"number_of_crimes"})

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 206124 entries, 0 to 206123
# Data columns (total 6 columns):
# year                206124 non-null int64
# month               206124 non-null int64
# day                 206124 non-null int64
# day_segment         206124 non-null category
# neighborhood        206124 non-null object
# number_of_crimes    206124 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 9.6+ MB

# %%
df10.isnull().sum()
# Out:
# year                0
# month               0
# day                 0
# day_segment         0
# neighborhood        0
# number_of_crimes    0
# dtype: int64

# %%
df10.iloc[7270,:]
# Out:
# year                               2003
# month                                 6
# day                                  12
# day_segment               0400pm-1159pm
# neighborhood        Victoria-Fraserview
# number_of_crimes                      3
# Name: 7270, dtype: object

# %%
df_final=df10.copy()

# %%
df_final.head()
# Out:
#    year  month  day    day_segment               neighborhood  \
# 0  2003      1    1  1200am-0759am  Central Business District
# 1  2003      1    1  1200am-0759am          Dunbar-Southlands
# 2  2003      1    1  1200am-0759am                   Fairview
# 3  2003      1    1  1200am-0759am         Grandview-Woodland
# 4  2003      1    1  1200am-0759am           Hastings-Sunrise
#
#    number_of_crimes
# 0                14
# 1                 1
# 2                 1
# 3                 6
# 4                 3

# %%
wdf=pd.read_csv('data/BA_weather_data.csv')

# %%
wdf_temp=wdf.copy()

# %%
wdf_temp.head()
# Out:
#    STN---  WBAN    YEARMODA  TMAX  TMIN     DEWP        SLP      .1    STP    \
# 0  727976  24217   20030101  44.8    24     37.2  24   1017.0    23   9999.9
# 1  727976  24217   20030102  49.5    23     43.3  23   1008.5    22   9999.9
# 2  727976  24217   20030103  51.0    24     40.6  24   1013.1    24   9999.9
# 3  727976  24217   20030104  49.7    24     43.0  24   1012.7    23   9999.9
# 4  727976  24217   20030105  46.4    24     42.6  24   1028.7    24   9999.9
#
#     ...      .3    WDSP    .4   MXSPD    GUST     MAX      MIN      PRCP  \
# 0   ...      24    11.9    24    20.0    28.0     48.2*    39.2*   0.00G
# 1   ...      23    18.2    23    35.9    53.0     55.4*    39.2*   0.54G
# 2   ...      24    14.3    24    33.0    42.9     55.4*    42.8*   0.17G
# 3   ...      24     8.9    24    22.9    30.9      57.9       43   0.08G
# 4   ...      24     6.0    24     9.9   999.9      57.9       39   0.39G
#
#    SNDP   FRSHTT
# 0  999.9   10000
# 1  999.9   10000
# 2  999.9   10010
# 3  999.9   10000
# 4  999.9       0
#
# [5 rows x 22 columns]

# %%
wdf2=wdf_temp[[' YEARMODA', 'TMAX', 'TMIN','PRCP']]
wdf2.head()
# Out:
#     YEARMODA  TMAX  TMIN    PRCP
# 0   20030101  44.8    24   0.00G
# 1   20030102  49.5    23   0.54G
# 2   20030103  51.0    24   0.17G
# 3   20030104  49.7    24   0.08G
# 4   20030105  46.4    24   0.39G

# %%
wdf3=wdf2.rename(index=str, columns={ " YEARMODA":"date","PRCP": "prcp", "TMAX":"tmax","TMIN":"tmin"})

# %%
def get_year(x):
    return int (str(x)[0:4])

def get_month(x):
    return int (str(x)[4:6])

def get_day(x):
    return int(str(x)[6:8])

def get_prcp(x):
    return float(x[1:5])
    
get_year(20030101)
# Out:
# 2003

# %%
wdf3['year'] = wdf3['date'].apply(get_year)
wdf3['month'] =  wdf3['date'].apply(get_month)
wdf3['day'] = wdf3['date'].apply(get_day)
wdf3['precipitation']=wdf3['prcp'].apply(get_prcp)

# %%
wdf3.head()
# Out:
#        date  tmax  tmin    prcp  year  month  day  precipitation
# 0  20030101  44.8    24   0.00G  2003      1    1           0.00
# 1  20030102  49.5    23   0.54G  2003      1    2           0.54
# 2  20030103  51.0    24   0.17G  2003      1    3           0.17
# 3  20030104  49.7    24   0.08G  2003      1    4           0.08
# 4  20030105  46.4    24   0.39G  2003      1    5           0.39

# %%
wdf4=wdf3[['year','month','day','tmax', 'tmin', 'precipitation']]

# %%
wdf4.head()
# Out:
#    year  month  day  tmax  tmin  precipitation
# 0  2003      1    1  44.8    24           0.00
# 1  2003      1    2  49.5    23           0.54
# 2  2003      1    3  51.0    24           0.17
# 3  2003      1    4  49.7    24           0.08
# 4  2003      1    5  46.4    24           0.39

# %%
wdf4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5478 entries, 0 to 5477
# Data columns (total 6 columns):
# year             5478 non-null int64
# month            5478 non-null int64
# day              5478 non-null int64
# tmax             5478 non-null float64
# tmin             5478 non-null int64
# precipitation    5478 non-null float64
# dtypes: float64(2), int64(4)
# memory usage: 299.6+ KB

# %%
wdf_final=wdf4.copy()

# %%
wdf_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5478 entries, 0 to 5477
# Data columns (total 6 columns):
# year             5478 non-null int64
# month            5478 non-null int64
# day              5478 non-null int64
# tmax             5478 non-null float64
# tmin             5478 non-null int64
# precipitation    5478 non-null float64
# dtypes: float64(2), int64(4)
# memory usage: 299.6+ KB

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 206124 entries, 0 to 206123
# Data columns (total 6 columns):
# year                206124 non-null int64
# month               206124 non-null int64
# day                 206124 non-null int64
# day_segment         206124 non-null category
# neighborhood        206124 non-null object
# number_of_crimes    206124 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 9.6+ MB

# %%
wdf_final.head()
# Out:
#    year  month  day  tmax  tmin  precipitation
# 0  2003      1    1  44.8    24           0.00
# 1  2003      1    2  49.5    23           0.54
# 2  2003      1    3  51.0    24           0.17
# 3  2003      1    4  49.7    24           0.08
# 4  2003      1    5  46.4    24           0.39

# %%
df_final.tail(10)
# Out:
#         year  month  day    day_segment               neighborhood  \
# 206114  2017     12   31  0400pm-1159pm  Central Business District
# 206115  2017     12   31  0400pm-1159pm         Grandview-Woodland
# 206116  2017     12   31  0400pm-1159pm                  Killarney
# 206117  2017     12   31  0400pm-1159pm                  Kitsilano
# 206118  2017     12   31  0400pm-1159pm             Mount Pleasant
# 206119  2017     12   31  0400pm-1159pm        Renfrew-Collingwood
# 206120  2017     12   31  0400pm-1159pm                Shaughnessy
# 206121  2017     12   31  0400pm-1159pm                 Strathcona
# 206122  2017     12   31  0400pm-1159pm                     Sunset
# 206123  2017     12   31  0400pm-1159pm                   West End
#
#         number_of_crimes
# 206114                17
# 206115                 1
# 206116                 3
# 206117                 1
# 206118                 3
# 206119                 2
# 206120                 1
# 206121                 2
# 206122                 3
# 206123                 3

# %%
wdf_final.tail(10)
# Out:
#       year  month  day  tmax  tmin  precipitation
# 5468  2017     12   22  34.2    24           0.00
# 5469  2017     12   23  30.6    24           0.00
# 5470  2017     12   24  28.0    24           0.00
# 5471  2017     12   25  30.9    24           0.00
# 5472  2017     12   26  29.6    24           0.00
# 5473  2017     12   27  28.8    24           0.00
# 5474  2017     12   28  33.7    24           0.16
# 5475  2017     12   29  37.0    24           0.31
# 5476  2017     12   30  38.1    24           0.72
# 5477  2017     12   31  30.2    24           0.01

# %%
new_df1=pd.merge(wdf_final,df_final, how='left', on=['year','month','day'])

# %%
new_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206074 entries, 0 to 206073
# Data columns (total 9 columns):
# year                206074 non-null int64
# month               206074 non-null int64
# day                 206074 non-null int64
# tmax                206074 non-null float64
# tmin                206074 non-null int64
# precipitation       206074 non-null float64
# day_segment         206074 non-null category
# neighborhood        206074 non-null object
# number_of_crimes    206074 non-null int64
# dtypes: category(1), float64(2), int64(5), object(1)
# memory usage: 14.3+ MB

# %%
new_df1.isnull().sum()
# Out:
# year                0
# month               0
# day                 0
# tmax                0
# tmin                0
# precipitation       0
# day_segment         0
# neighborhood        0
# number_of_crimes    0
# dtype: int64

# %%
cpi_df=pd.read_csv('data/consumer_price_index_nohead.csv')
cpi_df2=cpi_df.copy()

# %%
cpi_df2['year'] = cpi_df2.date.str.split('-').str.get(1)
cpi_df2['month'] = cpi_df2.date.str.split('-').str.get(0) 
cpi_df2.drop('date', axis=1,inplace=True)

# %%
import calendar
d=dict((v,k) for k,v in enumerate(calendar.month_abbr))
cpi_df2.month=cpi_df2.month.map(d)

cpi_df2.year='20'+ cpi_df2.year

# %%
cpi_df2=cpi_df2.apply(pd.to_numeric, errors='ignore')

# %%
new_df2=pd.merge(new_df1,cpi_df2, how='inner', on=['year','month'])

# %%
new_df2.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206074 entries, 0 to 206073
# Data columns (total 10 columns):
# year                    206074 non-null int64
# month                   206074 non-null int64
# day                     206074 non-null int64
# tmax                    206074 non-null float64
# tmin                    206074 non-null int64
# precipitation           206074 non-null float64
# day_segment             206074 non-null category
# neighborhood            206074 non-null object
# number_of_crimes        206074 non-null int64
# consumer_price_index    206074 non-null float64
# dtypes: category(1), float64(3), int64(5), object(1)
# memory usage: 15.9+ MB

# %%
new_df2.isnull().sum()
# Out:
# year                    0
# month                   0
# day                     0
# tmax                    0
# tmin                    0
# precipitation           0
# day_segment             0
# neighborhood            0
# number_of_crimes        0
# consumer_price_index    0
# dtype: int64

# %%
gdp_dftemp=pd.read_csv('data/gdp_2007dollars_nohead.csv')

# %%
gdp_df=gdp_dftemp.copy()

# %%
gdp_df.head()
# Out:
#      date  gdp_millions_2007
# 0  Jan-03            1305716
# 1  Feb-03            1309824
# 2  Mar-03            1309047
# 3  Apr-03            1305168
# 4  May-03            1309303

# %%
gdp_df['year'] = gdp_df.date.str.split('-').str.get(1)
gdp_df['month'] = gdp_df.date.str.split('-').str.get(0) 
gdp_df.drop('date', axis=1,inplace=True)

# %%
import calendar
d=dict((v,k) for k,v in enumerate(calendar.month_abbr))
gdp_df.month=gdp_df.month.map(d)

gdp_df.year='20'+ gdp_df.year

# %%
gdp_df=gdp_df.apply(pd.to_numeric, errors='ignore')

# %%
new_df3=pd.merge(new_df2,gdp_df, how='inner', on=['year','month'])

# %%
new_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206074 entries, 0 to 206073
# Data columns (total 11 columns):
# year                    206074 non-null int64
# month                   206074 non-null int64
# day                     206074 non-null int64
# tmax                    206074 non-null float64
# tmin                    206074 non-null int64
# precipitation           206074 non-null float64
# day_segment             206074 non-null category
# neighborhood            206074 non-null object
# number_of_crimes        206074 non-null int64
# consumer_price_index    206074 non-null float64
# gdp_millions_2007       206074 non-null int64
# dtypes: category(1), float64(3), int64(6), object(1)
# memory usage: 17.5+ MB

# %%
new_df3.isnull().sum()
# Out:
# year                    0
# month                   0
# day                     0
# tmax                    0
# tmin                    0
# precipitation           0
# day_segment             0
# neighborhood            0
# number_of_crimes        0
# consumer_price_index    0
# gdp_millions_2007       0
# dtype: int64

# %%
new_df3.head()
# Out:
#    year  month  day  tmax  tmin  precipitation    day_segment  \
# 0  2003      1    1  44.8    24            0.0  1200am-0759am
# 1  2003      1    1  44.8    24            0.0  1200am-0759am
# 2  2003      1    1  44.8    24            0.0  1200am-0759am
# 3  2003      1    1  44.8    24            0.0  1200am-0759am
# 4  2003      1    1  44.8    24            0.0  1200am-0759am
#
#                 neighborhood  number_of_crimes  consumer_price_index  \
# 0  Central Business District                14                 100.9
# 1          Dunbar-Southlands                 1                 100.9
# 2                   Fairview                 1                 100.9
# 3         Grandview-Woodland                 6                 100.9
# 4           Hastings-Sunrise                 3                 100.9
#
#    gdp_millions_2007
# 0            1305716
# 1            1305716
# 2            1305716
# 3            1305716
# 4            1305716

# %%
emp_df_init=pd.read_csv('data/employment_nohead.csv')
emp_df=emp_df_init.copy()

# %%
emp_df.head()
# Out:
#      date  seasonally_adjusted_unemployment  unadjusted_unemployment
# 0  Jan-03                               7.9                      7.5
# 1  Feb-03                               7.6                      7.5
# 2  Mar-03                               7.0                      7.2
# 3  Apr-03                               7.1                      7.1
# 4  May-03                               7.2                      7.1

# %%
emp_df['year'] = emp_df.date.str.split('-').str.get(1)
emp_df['month'] = emp_df.date.str.split('-').str.get(0) 
emp_df.drop('date', axis=1,inplace=True)

# %%
import calendar
d=dict((v,k) for k,v in enumerate(calendar.month_abbr))
emp_df.month=emp_df.month.map(d)

emp_df.year='20'+ emp_df.year

# %%
emp_df=emp_df.apply(pd.to_numeric, errors='ignore')

# %%
new_df4=pd.merge(new_df3,emp_df, how='inner', on=['year','month'])

# %%
new_df4.head()
# Out:
#    year  month  day  tmax  tmin  precipitation    day_segment  \
# 0  2003      1    1  44.8    24            0.0  1200am-0759am
# 1  2003      1    1  44.8    24            0.0  1200am-0759am
# 2  2003      1    1  44.8    24            0.0  1200am-0759am
# 3  2003      1    1  44.8    24            0.0  1200am-0759am
# 4  2003      1    1  44.8    24            0.0  1200am-0759am
#
#                 neighborhood  number_of_crimes  consumer_price_index  \
# 0  Central Business District                14                 100.9
# 1          Dunbar-Southlands                 1                 100.9
# 2                   Fairview                 1                 100.9
# 3         Grandview-Woodland                 6                 100.9
# 4           Hastings-Sunrise                 3                 100.9
#
#    gdp_millions_2007  seasonally_adjusted_unemployment  \
# 0            1305716                               7.9
# 1            1305716                               7.9
# 2            1305716                               7.9
# 3            1305716                               7.9
# 4            1305716                               7.9
#
#    unadjusted_unemployment
# 0                      7.5
# 1                      7.5
# 2                      7.5
# 3                      7.5
# 4                      7.5

# %%
new_df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206074 entries, 0 to 206073
# Data columns (total 13 columns):
# year                                206074 non-null int64
# month                               206074 non-null int64
# day                                 206074 non-null int64
# tmax                                206074 non-null float64
# tmin                                206074 non-null int64
# precipitation                       206074 non-null float64
# day_segment                         206074 non-null category
# neighborhood                        206074 non-null object
# number_of_crimes                    206074 non-null int64
# consumer_price_index                206074 non-null float64
# gdp_millions_2007                   206074 non-null int64
# seasonally_adjusted_unemployment    206074 non-null float64
# unadjusted_unemployment             206074 non-null float64
# dtypes: category(1), float64(5), int64(6), object(1)
# memory usage: 20.6+ MB

# %%
new_df4.isnull().sum()
# Out:
# year                                0
# month                               0
# day                                 0
# tmax                                0
# tmin                                0
# precipitation                       0
# day_segment                         0
# neighborhood                        0
# number_of_crimes                    0
# consumer_price_index                0
# gdp_millions_2007                   0
# seasonally_adjusted_unemployment    0
# unadjusted_unemployment             0
# dtype: int64

# %%
new_df4.head(10)
# Out:
#    year  month  day  tmax  tmin  precipitation    day_segment  \
# 0  2003      1    1  44.8    24            0.0  1200am-0759am
# 1  2003      1    1  44.8    24            0.0  1200am-0759am
# 2  2003      1    1  44.8    24            0.0  1200am-0759am
# 3  2003      1    1  44.8    24            0.0  1200am-0759am
# 4  2003      1    1  44.8    24            0.0  1200am-0759am
# 5  2003      1    1  44.8    24            0.0  1200am-0759am
# 6  2003      1    1  44.8    24            0.0  1200am-0759am
# 7  2003      1    1  44.8    24            0.0  1200am-0759am
# 8  2003      1    1  44.8    24            0.0  1200am-0759am
# 9  2003      1    1  44.8    24            0.0  1200am-0759am
#
#                 neighborhood  number_of_crimes  consumer_price_index  \
# 0  Central Business District                14                 100.9
# 1          Dunbar-Southlands                 1                 100.9
# 2                   Fairview                 1                 100.9
# 3         Grandview-Woodland                 6                 100.9
# 4           Hastings-Sunrise                 3                 100.9
# 5   Kensington-Cedar Cottage                 3                 100.9
# 6                 Kerrisdale                 1                 100.9
# 7                  Killarney                 1                 100.9
# 8                  Kitsilano                 3                 100.9
# 9                    Marpole                 3                 100.9
#
#    gdp_millions_2007  seasonally_adjusted_unemployment  \
# 0            1305716                               7.9
# 1            1305716                               7.9
# 2            1305716                               7.9
# 3            1305716                               7.9
# 4            1305716                               7.9
# 5            1305716                               7.9
# 6            1305716                               7.9
# 7            1305716                               7.9
# 8            1305716                               7.9
# 9            1305716                               7.9
#
#    unadjusted_unemployment
# 0                      7.5
# 1                      7.5
# 2                      7.5
# 3                      7.5
# 4                      7.5
# 5                      7.5
# 6                      7.5
# 7                      7.5
# 8                      7.5
# 9                      7.5

# %%
drugs_init=pd.read_csv('data/drug_offences_2006_to_2016.csv')
drugs_init
# Out:
#     year  Total Drug violations   Possession, cocaine   Heroin, possession   \
# 0   2006                   25630                  4682                  515
# 1   2007                   28472                  4428                  378
# 2   2008                   27032                  3992                  389
# 3   2009                   23948                  2891                  347
# 4   2010                   26928                  2642                  316
# 5   2011                   27178                  2524                  379
# 6   2012                   25455                  2597                  508
# 7   2013                   26354                  2654                  617
# 8   2014                   24321                  2310                  853
# 9   2015                   22132                  2068                 1139
# 10  2016                   21507                  2047                 1550
#
#     Other Controlled Drugs and Substances Act, possession  \
# 0                                                1562
# 1                                                2265
# 2                                                1881
# 3                                                1079
# 4                                                1165
# 5                                                1196
# 6                                                1106
# 7                                                 997
# 8                                                1130
# 9                                                1278
# 10                                               1575
#
#     Methamphetamines (crystal meth), possession
# 0                                              1
# 1                                            306
# 2                                            334
# 3                                            310
# 4                                            429
# 5                                            539
# 6                                            663
# 7                                           1058
# 8                                           1549
# 9                                           1828
# 10                                          2153

# %%
drugs_init.columns
# Out:
# Index(['year', 'Total Drug violations ', 'Possession, cocaine ',
#        'Heroin, possession ',
#        'Other Controlled Drugs and Substances Act, possession',
#        'Methamphetamines (crystal meth), possession '],
#       dtype='object')

# %%
drugs_df=drugs_init.copy()

# %%
drugs_df2=drugs_df[['year','Possession, cocaine ',
       'Heroin, possession ',]]

# %%
drugs_df3=drugs_df2.copy()

# %%
drugs_df3.loc[11]=[2017, 2047,1550]

# %%
drugs_df3.loc[12]=[2003, 4682,515]
drugs_df3.loc[13]=[2004, 4682,515]
drugs_df3.loc[14]=[2005, 4682,515]

# %%
drugs_df3
# Out:
#     year  Possession, cocaine   Heroin, possession
# 0   2006                  4682                  515
# 1   2007                  4428                  378
# 2   2008                  3992                  389
# 3   2009                  2891                  347
# 4   2010                  2642                  316
# 5   2011                  2524                  379
# 6   2012                  2597                  508
# 7   2013                  2654                  617
# 8   2014                  2310                  853
# 9   2015                  2068                 1139
# 10  2016                  2047                 1550
# 11  2017                  2047                 1550
# 12  2003                  4682                  515
# 13  2004                  4682                  515
# 14  2005                  4682                  515

# %%
new_df5=pd.merge(new_df4,drugs_df3, how='inner', on=['year'])

# %%
new_df5.head(10)
# Out:
#    year  month  day  tmax  tmin  precipitation    day_segment  \
# 0  2003      1    1  44.8    24            0.0  1200am-0759am
# 1  2003      1    1  44.8    24            0.0  1200am-0759am
# 2  2003      1    1  44.8    24            0.0  1200am-0759am
# 3  2003      1    1  44.8    24            0.0  1200am-0759am
# 4  2003      1    1  44.8    24            0.0  1200am-0759am
# 5  2003      1    1  44.8    24            0.0  1200am-0759am
# 6  2003      1    1  44.8    24            0.0  1200am-0759am
# 7  2003      1    1  44.8    24            0.0  1200am-0759am
# 8  2003      1    1  44.8    24            0.0  1200am-0759am
# 9  2003      1    1  44.8    24            0.0  1200am-0759am
#
#                 neighborhood  number_of_crimes  consumer_price_index  \
# 0  Central Business District                14                 100.9
# 1          Dunbar-Southlands                 1                 100.9
# 2                   Fairview                 1                 100.9
# 3         Grandview-Woodland                 6                 100.9
# 4           Hastings-Sunrise                 3                 100.9
# 5   Kensington-Cedar Cottage                 3                 100.9
# 6                 Kerrisdale                 1                 100.9
# 7                  Killarney                 1                 100.9
# 8                  Kitsilano                 3                 100.9
# 9                    Marpole                 3                 100.9
#
#    gdp_millions_2007  seasonally_adjusted_unemployment  \
# 0            1305716                               7.9
# 1            1305716                               7.9
# 2            1305716                               7.9
# 3            1305716                               7.9
# 4            1305716                               7.9
# 5            1305716                               7.9
# 6            1305716                               7.9
# 7            1305716                               7.9
# 8            1305716                               7.9
# 9            1305716                               7.9
#
#    unadjusted_unemployment  Possession, cocaine   Heroin, possession
# 0                      7.5                  4682                  515
# 1                      7.5                  4682                  515
# 2                      7.5                  4682                  515
# 3                      7.5                  4682                  515
# 4                      7.5                  4682                  515
# 5                      7.5                  4682                  515
# 6                      7.5                  4682                  515
# 7                      7.5                  4682                  515
# 8                      7.5                  4682                  515
# 9                      7.5                  4682                  515
