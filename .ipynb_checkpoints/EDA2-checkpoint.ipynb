# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data/crime_csv_all_years.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560741 entries, 0 to 560740
# Data columns (total 10 columns):
# TYPE             560741 non-null object
# YEAR             560741 non-null int64
# MONTH            560741 non-null int64
# DAY              560741 non-null int64
# HOUR             503868 non-null float64
# MINUTE           503868 non-null float64
# HUNDRED_BLOCK    560728 non-null object
# NEIGHBOURHOOD    501541 non-null object
# X                560741 non-null float64
# Y                560741 non-null float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 42.8+ MB

# %%
df.head()
# Out:
#                          TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0          Theft from Vehicle  2003     11   23   0.0     1.0
# 1          Theft from Vehicle  2003      5    9  18.0     0.0
# 2    Offence Against a Person  2003      3    9   NaN     NaN
# 3    Offence Against a Person  2003      1   20   NaN     NaN
# 4  Break and Enter Commercial  2003      2    7   0.0    30.0
#
#                HUNDRED_BLOCK              NEIGHBOURHOOD          X           Y
# 0          13XX W GEORGIA ST  Central Business District  490745.08  5459529.81
# 1             30XX W 8TH AVE                  Kitsilano  487465.51  5456929.11
# 2  OFFSET TO PROTECT PRIVACY                        NaN       0.00        0.00
# 3  OFFSET TO PROTECT PRIVACY                        NaN       0.00        0.00
# 4           71XX VICTORIA DR        Victoria-Fraserview  495196.35  5451832.55

# %%
df.isnull().sum()
# Out:
# TYPE                 0
# YEAR                 0
# MONTH                0
# DAY                  0
# HOUR             56873
# MINUTE           56873
# HUNDRED_BLOCK       13
# NEIGHBOURHOOD    59200
# X                    0
# Y                    0
# dtype: int64

# %%
df.nunique()
# Out:
# TYPE                 11
# YEAR                 16
# MONTH                12
# DAY                  31
# HOUR                 24
# MINUTE               60
# HUNDRED_BLOCK     21506
# NEIGHBOURHOOD        24
# X                103425
# Y                101082
# dtype: int64

# %%
df2=df.dropna()

# %%
df2.nunique()
# Out:
# TYPE                  9
# YEAR                 16
# MONTH                12
# DAY                  31
# HOUR                 24
# MINUTE               60
# HUNDRED_BLOCK     21494
# NEIGHBOURHOOD        24
# X                103405
# Y                101069
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# TYPE             0
# YEAR             0
# MONTH            0
# DAY              0
# HOUR             0
# MINUTE           0
# HUNDRED_BLOCK    0
# NEIGHBOURHOOD    0
# X                0
# Y                0
# dtype: int64

# %%
df3=df2.sort_values(['YEAR','MONTH','DAY','HOUR','MINUTE'])

# %%
df3.head(100)
# Out:
#                                                     TYPE  YEAR  MONTH  DAY  \
# 2148                                  Theft from Vehicle  2003      1    1
# 3215                                    Theft of Bicycle  2003      1    1
# 7453                                  Theft from Vehicle  2003      1    1
# 18527                                           Mischief  2003      1    1
# 32204                                 Theft from Vehicle  2003      1    1
# 34232                                 Theft from Vehicle  2003      1    1
# 34819                                 Theft from Vehicle  2003      1    1
# 45038                  Break and Enter Residential/Other  2003      1    1
# 48249                         Break and Enter Commercial  2003      1    1
# 48331                                 Theft from Vehicle  2003      1    1
# 48386                                   Theft of Bicycle  2003      1    1
# ...

# %%
df3['YEAR'].value_counts().sort_index()
# Out:
# 2003    45885
# 2004    45035
# 2005    40522
# 2006    37767
# 2007    33161
# 2008    31070
# 2009    28197
# 2010    25876
# 2011    24633
# 2012    25378
# 2013    25324
# 2014    29433
# 2015    31019
# 2016    34534
# 2017    33625
# 2018    10069
# Name: YEAR, dtype: int64

# %%
# Out:
#   File "<ipython-input-13-9e9aa3537a37>", line 1
#     CensusLocalAreaProfiles2016.csv	eng-almanac-0101-1231.csv
#                                    	  ^
# SyntaxError: invalid syntax

# %%
pwd
# Out:
# '/Users/michaeljoyce/Desktop/Capstone'

# %%
wdf=pd.read_csv('data/Blaine.csv')

# %%
wdf.head()
# Out:
#        STATION           NAME        DATE  MDPR  PRCP  SNOW  SNWD  TMAX  TMIN  \
# 0  USC00450729  BLAINE, WA US  2003-01-01   NaN  0.43   0.0   0.0  45.0  38.0
# 1  USC00450729  BLAINE, WA US  2003-01-02   NaN  0.87   0.0   0.0  54.0  39.0
# 2  USC00450729  BLAINE, WA US  2003-01-03   NaN  0.33   0.0   0.0  54.0  40.0
# 3  USC00450729  BLAINE, WA US  2003-01-04   NaN  0.77   0.0   0.0  53.0  43.0
# 4  USC00450729  BLAINE, WA US  2003-01-05   NaN  0.00   0.0   0.0  52.0  37.0
#
#    TOBS  WT01
# 0  39.0   NaN
# 1  54.0   NaN
# 2  47.0   NaN
# 3  51.0   NaN
# 4  47.0   NaN

# %%
wdf2=wdf[['DATE','PRCP','TMIN']]

# %%
df2['X'].max()-df2['X'].min()

# %%
df2['Y'].max()

# %%
df2['Y'].min()

# %%
df2['Y'].max()-df2['Y'].min()

# %%
df[''].groupby(df.birthdate.dt.to_period("M")).agg('count')

# %%
cd data

# %%
ls

# %%
cd ..

# %%
df
