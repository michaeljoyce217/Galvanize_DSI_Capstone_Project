# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data/crime_csv_all_years.csv')

# %%
df.dropna(inplace=True)
#remove missing data, all (or nearly all) of which is the non-property crime data

# %%
df.rename(index=str, columns={"YEAR": "year", "MONTH": "month", "DAY":"day","HOUR":"hour", "MINUTE":"minute", "NEIGHBOURHOOD":"neighbourhood"},inplace=True)
#rename columns as all caps is annoying

# %%
df.head()
# Out:
#                          TYPE  year  month  day  hour  minute  \
# 0          Theft from Vehicle  2003     11   23   0.0     1.0
# 1          Theft from Vehicle  2003      5    9  18.0     0.0
# 4  Break and Enter Commercial  2003      2    7   0.0    30.0
# 5  Break and Enter Commercial  2003      6    2   3.0     4.0
# 6                    Mischief  2003     12   31   8.0    40.0
#
#        HUNDRED_BLOCK              neighbourhood          X           Y
# 0  13XX W GEORGIA ST  Central Business District  490745.08  5459529.81
# 1     30XX W 8TH AVE                  Kitsilano  487465.51  5456929.11
# 4   71XX VICTORIA DR        Victoria-Fraserview  495196.35  5451832.55
# 5   71XX VICTORIA DR        Victoria-Fraserview  495196.35  5451832.55
# 6  10XX W GEORGIA ST                   West End  491128.32  5459137.86

# %%
df.sort_values(['year','month','day','hour','minute'],inplace=True)
#sort by date

# %%
df.drop(['minute', 'HUNDRED_BLOCK','TYPE'], axis=1,inplace=True)
#remove extraneous data

# %%
df.apply(pd.to_numeric, errors='ignore')
# Out:
#         year  month  day  hour              neighbourhood          X  \
# 2148    2003      1    1   0.0  Central Business District  490968.94
# 3215    2003      1    1   0.0  Central Business District  492231.06
# 7453    2003      1    1   0.0                  Kitsilano  488324.36
# 18527   2003      1    1   0.0         Grandview-Woodland  494981.08
# 32204   2003      1    1   0.0  Central Business District  490849.97
# 34232   2003      1    1   0.0                     Sunset  494285.25
# 34819   2003      1    1   0.0                Shaughnessy  490707.25
# 45038   2003      1    1   0.0                   Fairview  490791.12
# 48249   2003      1    1   0.0        Victoria-Fraserview  495220.95
# 48331   2003      1    1   0.0                  Killarney  497388.60
# 48386   2003      1    1   0.0                  Kitsilano  487421.31
# 5783    2003      1    1   0.0        Victoria-Fraserview  496028.76
# 7935    2003      1    1   0.0          Dunbar-Southlands  486837.11
# 36817   2003      1    1   0.0  Central Business District  490705.34
# 9491    2003      1    1   0.0                   West End  490687.00
# 28294   2003      1    1   0.0         Grandview-Woodland  495279.46
# 12387   2003      1    1   0.0                    Marpole  489683.62
# 19542   2003      1    1   0.0  Central Business District  491613.02
# 38679   2003      1    1   0.0  Central Business District  492183.96
# 25321   2003      1    1   1.0                    Marpole  490174.85
# 37664   2003      1    1   1.0  Central Business District  491084.84
# 7887    2003      1    1   1.0           Hastings-Sunrise  495898.84
# 30338   2003      1    1   1.0                   West End  490830.09
# 20978   2003      1    1   1.0         Grandview-Woodland  495107.25
# 34610   2003      1    1   1.0                  Kitsilano  488772.00
# 17137   2003      1    1   1.0                 Riley Park  492627.84
# 21022   2003      1    1   1.0                 Riley Park  492627.84
# 12711   2003      1    1   2.0  Central Business District  491424.48
# 555614  5456952.73
# 554476  5452750.53
# 558919  5458643.00
# 553021  5457264.32
# 556514  5458931.50
# 550752  5458835.08
# 554165  5458397.69
# 558908  5459048.55
#
# [501528 rows x 7 columns]

# %%
#bin by 12am-8am, 8am-4pm, 4pm -12am
hourbins = [-0.1,8.0,16.0,24.1]
hourlabels = ['1200am-0759am', '0800am-0359pm', '0400pm-1159pm']
df['day_segment'] = pd.cut(df["hour"], bins=hourbins,labels=hourlabels)

# %%
df=df[['year', 'month', 'day', 'day_segment', 'neighbourhood']]
#group by neighborhood, by day_segment

# %%
df.head()
# Out:
#        year  month  day    day_segment              neighbourhood
# 2148   2003      1    1  1200am-0759am  Central Business District
# 3215   2003      1    1  1200am-0759am  Central Business District
# 7453   2003      1    1  1200am-0759am                  Kitsilano
# 18527  2003      1    1  1200am-0759am         Grandview-Woodland
# 32204  2003      1    1  1200am-0759am  Central Business District

# %%
df=df.groupby(df.columns.tolist()).size()

# %%
df=pd.DataFrame(df).reset_index()

# %%
df.rename(index=str, columns={ 0 :"number_of_crimes"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 210029 entries, 0 to 210028
# Data columns (total 6 columns):
# year                210029 non-null int64
# month               210029 non-null int64
# day                 210029 non-null int64
# day_segment         210029 non-null category
# neighbourhood       210029 non-null object
# number_of_crimes    210029 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 9.8+ MB

# %%
df.isnull().sum()
# Out:
# year                0
# month               0
# day                 0
# day_segment         0
# neighbourhood       0
# number_of_crimes    0
# dtype: int64

# %%
df
# Out:
#         year  month  day    day_segment              neighbourhood  \
# 0       2003      1    1  1200am-0759am  Central Business District
# 1       2003      1    1  1200am-0759am          Dunbar-Southlands
# 2       2003      1    1  1200am-0759am                   Fairview
# 3       2003      1    1  1200am-0759am         Grandview-Woodland
# 4       2003      1    1  1200am-0759am           Hastings-Sunrise
# 5       2003      1    1  1200am-0759am   Kensington-Cedar Cottage
# 6       2003      1    1  1200am-0759am                 Kerrisdale
# 7       2003      1    1  1200am-0759am                  Killarney
# 8       2003      1    1  1200am-0759am                  Kitsilano
# 9       2003      1    1  1200am-0759am                    Marpole
# 10      2003      1    1  1200am-0759am             Mount Pleasant
# 11      2003      1    1  1200am-0759am        Renfrew-Collingwood
# 12      2003      1    1  1200am-0759am                 Riley Park
# 13      2003      1    1  1200am-0759am                Shaughnessy
# 14      2003      1    1  1200am-0759am                 Strathcona
# 15      2003      1    1  1200am-0759am                     Sunset
# 16      2003      1    1  1200am-0759am        Victoria-Fraserview
# 17      2003      1    1  1200am-0759am                   West End
# 18      2003      1    1  0800am-0359pm              Arbutus Ridge
# 19      2003      1    1  0800am-0359pm  Central Business District
# 20      2003      1    1  0800am-0359pm         Grandview-Woodland
# 21      2003      1    1  0800am-0359pm           Hastings-Sunrise
# 22      2003      1    1  0800am-0359pm   Kensington-Cedar Cottage
# 23      2003      1    1  0800am-0359pm                  Killarney
# 24      2003      1    1  0800am-0359pm                  Kitsilano
# 25      2003      1    1  0800am-0359pm             Mount Pleasant

# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('year', 'month', 'day')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-88d6a5c53c61> in <module>()
# ----> 1 df['year','month','day'].nunique()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('year', 'month', 'day')

# %%
wdf=pd.read_csv('data/Blaine.csv')

# %%
wdf.head()
# Out:
#        STATION           NAME        DATE  MDPR  PRCP  SNOW  SNWD  TMAX  TMIN  \
# 0  USC00450729  BLAINE, WA US  2003-01-01   NaN  0.43   0.0   0.0  45.0  38.0
# 1  USC00450729  BLAINE, WA US  2003-01-02   NaN  0.87   0.0   0.0  54.0  39.0
# 2  USC00450729  BLAINE, WA US  2003-01-03   NaN  0.33   0.0   0.0  54.0  40.0
# 3  USC00450729  BLAINE, WA US  2003-01-04   NaN  0.77   0.0   0.0  53.0  43.0
# 4  USC00450729  BLAINE, WA US  2003-01-05   NaN  0.00   0.0   0.0  52.0  37.0
#
#    TOBS  WT01
# 0  39.0   NaN
# 1  54.0   NaN
# 2  47.0   NaN
# 3  51.0   NaN
# 4  47.0   NaN

# %%
wdf=wdf[['DATE','PRCP','TMAX','TMIN']]
wdf.rename(index=str, columns={ "PRCP": "prcp", "TMAX":"tmax","TMIN":"tmin"},inplace=True)

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4718 entries, 0 to 4717
# Data columns (total 4 columns):
# DATE    4718 non-null object
# prcp    4684 non-null float64
# tmax    4675 non-null float64
# tmin    4673 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 184.3+ KB

# %%
wdf.interpolate(inplace=True)

# %%
wdf.isnull().sum()
# Out:
# DATE    0
# prcp    0
# tmax    0
# tmin    0
# dtype: int64

# %%
wdf['year'] = wdf.DATE.str.split('-').str.get(0)
wdf['month'] = wdf.DATE.str.split('-').str.get(1) 
wdf['day'] = wdf.DATE.str.split('-').str.get(2) 
wdf.drop('DATE', axis=1,inplace=True)

# %%
wdf.head()
# Out:
#    prcp  tmax  tmin  year month day
# 0  0.43  45.0  38.0  2003    01  01
# 1  0.87  54.0  39.0  2003    01  02
# 2  0.33  54.0  40.0  2003    01  03
# 3  0.77  53.0  43.0  2003    01  04
# 4  0.00  52.0  37.0  2003    01  05

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4718 entries, 0 to 4717
# Data columns (total 6 columns):
# prcp     4718 non-null float64
# tmax     4718 non-null float64
# tmin     4718 non-null float64
# year     4718 non-null object
# month    4718 non-null object
# day      4718 non-null object
# dtypes: float64(3), object(3)
# memory usage: 258.0+ KB

# %%
wdf=wdf.apply(pd.to_numeric, errors='ignore')

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4718 entries, 0 to 4717
# Data columns (total 6 columns):
# prcp     4718 non-null float64
# tmax     4718 non-null float64
# tmin     4718 non-null float64
# year     4718 non-null int64
# month    4718 non-null int64
# day      4718 non-null int64
# dtypes: float64(3), int64(3)
# memory usage: 258.0+ KB

# %%
wdf
# Out:
#       prcp  tmax  tmin  year  month  day
# 0     0.43  45.0  38.0  2003      1    1
# 1     0.87  54.0  39.0  2003      1    2
# 2     0.33  54.0  40.0  2003      1    3
# 3     0.77  53.0  43.0  2003      1    4
# 4     0.00  52.0  37.0  2003      1    5
# 5     0.00  52.0  30.0  2003      1    6
# 6     0.00  51.0  29.0  2003      1    7
# 7     0.00  49.0  29.0  2003      1    8
# 8     0.00  50.0  32.0  2003      1    9
# 9     0.00  46.0  29.0  2003      1   10
# 10    0.00  42.0  28.0  2003      1   11
# 11    0.50  43.0  38.0  2003      1   12
# 12    0.00  45.0  36.0  2003      1   13
# 13    0.00  47.0  30.0  2003      1   14
# 14    0.11  45.0  31.0  2003      1   15
# 15    0.00  45.0  32.0  2003      1   16
# 16    0.00  43.0  29.0  2003      1   17
# 17    0.00  43.0  26.0  2003      1   18
# 18    0.02  43.0  30.0  2003      1   19
# 19    0.00  45.0  41.0  2003      1   20
# 20    0.00  44.0  34.0  2003      1   21
# 21    0.30  43.0  37.0  2003      1   22
# 22    0.60  54.0  38.0  2003      1   23
# 23    0.17  52.0  43.0  2003      1   24
# 24    0.14  50.0  45.0  2003      1   25
# 25    0.90  56.0  45.0  2003      1   26
# 26    0.10  53.0  45.0  2003      1   27
# 27    0.00  50.0  37.0  2003      1   28
# 28    0.43  48.0  36.0  2003      1   29
# 29    0.11  48.0  37.0  2003      1   30
# ...    ...   ...   ...   ...    ...  ...
# 4688  0.06  44.0  35.0  2018      1    9
# 4689  0.14  46.0  35.0  2018      1   10
# 4690  1.12  35.0  34.0  2018      1   11
# 4691  0.66  39.0  35.0  2018      1   12
# 4692  0.02  46.0  35.0  2018      1   13
# 4693  0.00  49.0  32.0  2018      1   14
# 4694  0.04  54.0  35.0  2018      1   15
# 4695  0.12  53.0  44.0  2018      1   16
# 4696  0.25  50.0  44.0  2018      1   17
# 4697  0.01  50.0  43.0  2018      1   18
# 4698  0.26  48.0  44.0  2018      1   19
# 4699  0.06  50.0  42.0  2018      1   20
# 4700  0.41  51.0  42.0  2018      1   21
# 4701  0.00  47.0  40.0  2018      1   22
# 4702  0.75  42.0  39.0  2018      1   23
# 4703  0.08  48.0  40.0  2018      1   24
# 4704  0.22  42.0  37.0  2018      1   25
# 4705  0.31  45.0  38.0  2018      1   26
# 4706  0.31  42.0  35.0  2018      1   27
# 4707  1.07  47.0  38.0  2018      1   28
# 4708  0.65  48.0  39.0  2018      1   29
# 4709  0.01  46.0  40.0  2018      1   30
# 4710  0.37  44.0  38.0  2018      1   31
# 4711  0.00  44.0  34.0  2018      2    9
# 4712  0.00  42.0  31.0  2018      2   10
# 4713  0.00  49.0  34.0  2018      2   21
# 4714  0.00  38.0  19.0  2018      2   22
# 4715  0.61  32.0  24.0  2018      2   23
# 4716  0.46  47.0  39.0  2018      3    8
# 4717  0.00  49.0  33.0  2018      3    9
#
# [4718 rows x 6 columns]

# %%
wdf.isnull().sum()
# Out:
# prcp     0
# tmax     0
# tmin     0
# year     0
# month    0
# day      0
# dtype: int64

# %%
new_df1=pd.merge(df,wdf, how='outer', on=['year','month','day'])

# %%
new_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 210029 entries, 0 to 210028
# Data columns (total 9 columns):
# year                210029 non-null int64
# month               210029 non-null int64
# day                 210029 non-null int64
# day_segment         210029 non-null category
# neighbourhood       210029 non-null object
# number_of_crimes    210029 non-null int64
# prcp                172029 non-null float64
# tmax                172029 non-null float64
# tmin                172029 non-null float64
# dtypes: category(1), float64(3), int64(4), object(1)
# memory usage: 14.6+ MB

# %%
new_df1.isnull().sum()

# %%
cpi_df=pd.read_csv('data/consumer_price_index_nohead.csv')

# %%
cpi_df['year'] = cpi_df.date.str.split('-').str.get(1)
cpi_df['month'] = cpi_df.date.str.split('-').str.get(0) 
cpi_df.drop('date', axis=1,inplace=True)

# %%
import calendar
d=dict((v,k) for k,v in enumerate(calendar.month_abbr))
cpi_df.month=cpi_df.month.map(d)

cpi_df.year='20'+ cpi_df.year

# %%
cpi_df=cpi_df.apply(pd.to_numeric, errors='ignore')

# %%
new_df2=pd.merge(new_df1,cpi_df, how='inner', on=['year','month'])

# %%
new_df2.info(0)

# %%
new_df2.isnull().sum()

# %%
gdp_df=pd.read_csv('data/gdp_2007dollars_nohead.csv')

# %%
gdp_df.head()

# %%
gdp_df['year'] = gdp_df.date.str.split('-').str.get(1)
gdp_df['month'] = gdp_df.date.str.split('-').str.get(0) 
gdp_df.drop('date', axis=1,inplace=True)

# %%
import calendar
d=dict((v,k) for k,v in enumerate(calendar.month_abbr))
gdp_df.month=gdp_df.month.map(d)

gdp_df.year='20'+ gdp_df.year

# %%
gdp_df=gdp_df.apply(pd.to_numeric, errors='ignore')

# %%
new_df3=pd.merge(new_df2,gdp_df, how='inner', on=['year','month'])

# %%
new_df3.info()

# %%
new_df3.isnull().sum()

# %%
emp_df=pd.read_csv('data/employment_nohead.csv')

# %%
emp_df.head()

# %%
emp_df['year'] = emp_df.date.str.split('-').str.get(1)
emp_df['month'] = emp_df.date.str.split('-').str.get(0) 
emp_df.drop('date', axis=1,inplace=True)

# %%
import calendar
d=dict((v,k) for k,v in enumerate(calendar.month_abbr))
emp_df.month=emp_df.month.map(d)

emp_df.year='20'+ emp_df.year

# %%
emp_df=emp_df.apply(pd.to_numeric, errors='ignore')

# %%
new_df4=pd.merge(new_df3,emp_df, how='inner', on=['year','month'])

# %%
new_df4.head()

# %%
new_df4.info()

# %%
new_df4.isnull().sum()
