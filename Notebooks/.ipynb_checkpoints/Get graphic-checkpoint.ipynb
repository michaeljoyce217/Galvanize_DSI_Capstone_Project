# %%
import pandas as pd
import matplotlib
# %matplotlib inline
import seaborn as sns

# %%
coefficients=pd.read_csv('/Users/michaeljoyce/Desktop/Capstone/Notebooks/more.csv')
coefficients.columns
# Out:
# Index(['Unnamed: 0', 'All data', 'VPD only'], dtype='object')

# %%
coeff2=coefficients.set_index('Unnamed: 0')

# %%
coeff2.plot(kind='barh')

# %%
coefficients.head()

# %%
coeff_all=coefficients.drop(coefficients['VPD only'])
coeff_all

# %%
sns.barplot(x='Unnamed: 0',y='All data', data=coefficients, );
